# %% [markdown]
# #### Api de equipos

# %%
import requests
import json

url = "http://api.sofascore.com/api/v1/team/2817"

# Realizar la solicitud GET
response = requests.get(url)

# Verificar que la solicitud fue exitosa
if response.status_code == 200:
    # Extraer el JSON de la respuesta
    data = response.json()
    # Imprimir el JSON de manera bonita
    pretty_json = json.dumps(data, indent=4)
    print(pretty_json)
else:
    print("Error en la solicitud:", response.status_code)
# Out:
# {
#     "team": {
#         "name": "Barcelona",
#         "slug": "barcelona",
#         "shortName": "Barcelona",
#         "gender": "M",
#         "sport": {
#             "name": "Football",
#             "slug": "football",
#             "id": 1
#         },
#         "category": {
#             "name": "Spain",
#             "slug": "spain",
#             "sport": {
#                 "name": "Football",
#                 "slug": "football",
#                 "id": 1
#             },
#             "id": 32,
#             "country": {
#                 "alpha2": "ES",
#                 "alpha3": "ESP",
#                 "name": "Spain"
#             },
#             "flag": "spain",
#             "alpha2": "ES"
#         },
#         "tournament": {
#             "name": "LaLiga",
#             "slug": "laliga",
#             "category": {
#                 "name": "Spain",
#                 "slug": "spain",
#                 "sport": {
#                     "name": "Football",
#                     "slug": "football",
#                     "id": 1
#                 },
#                 "id": 32,
#                 "country": {
#                     "alpha2": "ES",
#                     "alpha3": "ESP",
#                     "name": "Spain"
#                 },
#                 "flag": "spain",
#                 "alpha2": "ES"
#             },
#             "uniqueTournament": {
#                 "name": "LaLiga",
#                 "slug": "laliga",
#                 "primaryColorHex": "#2f4a89",
#                 "secondaryColorHex": "#f4a32e",
#                 "category": {
#                     "name": "Spain",
#                     "slug": "spain",
#                     "sport": {
#                         "name": "Football",
#                         "slug": "football",
#                         "id": 1
#                     },
#                     "id": 32,
#                     "country": {
#                         "alpha2": "ES",
#                         "alpha3": "ESP",
#                         "name": "Spain"
#                     },
#                     "flag": "spain",
#                     "alpha2": "ES"
#                 },
#                 "userCount": 1126899,
#                 "hasPerformanceGraphFeature": true,
#                 "id": 8,
#                 "country": {},
#                 "displayInverseHomeAwayTeams": false
#             },
#             "priority": 599,
#             "isLive": false,
#             "id": 36
#         },
#         "primaryUniqueTournament": {
#             "name": "LaLiga",
#             "slug": "laliga",
#             "primaryColorHex": "#2f4a89",
#             "secondaryColorHex": "#f4a32e",
#             "category": {
#                 "name": "Spain",
#                 "slug": "spain",
#                 "sport": {
#                     "name": "Football",
#                     "slug": "football",
#                     "id": 1
#                 },
#                 "id": 32,
#                 "country": {
#                     "alpha2": "ES",
#                     "alpha3": "ESP",
#                     "name": "Spain"
#                 },
#                 "flag": "spain",
#                 "alpha2": "ES"
#             },
#             "userCount": 1126899,
#             "hasPerformanceGraphFeature": true,
#             "id": 8,
#             "country": {},
#             "displayInverseHomeAwayTeams": false
#         },
#         "userCount": 2422772,
#         "manager": {
#             "name": "Xavi",
#             "slug": "xavi",
#             "shortName": "Xavi",
#             "id": 792281,
#             "country": {
#                 "alpha2": "ES",
#                 "alpha3": "ESP",
#                 "name": "Spain"
#             },
#             "fieldTranslations": {
#                 "nameTranslation": {
#                     "ar": "\u0632\u0627\u0641\u064a"
#                 },
#                 "shortNameTranslation": {
#                     "ar": "\u0632\u0627\u0641\u064a"
#                 }
#             }
#         },
#         "venue": {
#             "city": {
#                 "name": "Barcelona"
#             },
#             "stadium": {
#                 "name": "Ol\u00edmpic Llu\u00eds Companys",
#                 "capacity": 54367
#             },
#             "id": 714,
#             "country": {
#                 "alpha2": "ES",
#                 "alpha3": "ESP",
#                 "name": "Spain"
#             },
#             "fieldTranslations": {
#                 "nameTranslation": {
#                     "ar": "\u0627\u0648\u0644\u064a\u0645\u067e\u064a\u0643 \u0644\u0648\u064a\u0633 \u0643\u0648\u0645\u067e\u0627\u0646\u064a\u0633"
#                 },
#                 "shortNameTranslation": {}
#             }
#         },
#         "foundationDate": {},
#         "nameCode": "FCB",
#         "disabled": false,
#         "national": false,
#         "type": 0,
#         "id": 2817,
#         "country": {
#             "alpha2": "ES",
#             "alpha3": "ESP",
#             "name": "Spain"
#         },
#         "fullName": "Barcelona",
#         "teamColors": {
#             "primary": "#154284",
#             "secondary": "#9d1009",
#             "text": "#9d1009"
#         },
#         "foundationDateTimestamp": -2211840000,
#         "fieldTranslations": {
#             "nameTranslation": {
#                 "ar": "\u0628\u0631\u0634\u0644\u0648\u0646\u0629",
#                 "ru": "\u0411\u0430\u0440\u0441\u0435\u043b\u043e\u043d\u0430"
#             },
#             "shortNameTranslation": {}
#         }
#     }
# }

# %% [markdown]
# ### Lista de equipos de primera

# %%
import requests
import csv
import time

def fetch_team_data(team_id):
    """ Realiza una solicitud al API para obtener datos de un equipo específico. """
    url = f"http://api.sofascore.com/api/v1/team/{team_id}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        team = data.get('team', {})
        if team:
            # Extraer la información del género del equipo
            gender = team.get('gender', 'Unknown')  # Por defecto 'Unknown' si no está especificado
            primary_tournament = team.get('primaryUniqueTournament', {}).get('name', 'No Tournament')
            sport = team.get('sport', {}).get('name', 'No Sport')
            return {
                'id': team_id,
                'name': team.get('name', 'No Name'),
                'country': team.get('category', {}).get('country', {}).get('name', 'No Country'),
                'sport': sport,
                'primary_tournament': primary_tournament,
                'gender': gender  # Añadir el género
            }
    return None

#Fuerza bruta
# Preparar el archivo CSV y el escritor de CSV
# with open('teams.csv', 'w', newline='') as file:
#     fieldnames = ['id', 'name', 'country', 'sport', 'primary_tournament', 'gender']  # Añadir 'gender' a los nombres de los campos
#     writer = csv.DictWriter(file, fieldnames=fieldnames)
#     writer.writeheader()

#     # Realizar las solicitudes y escribir cada equipo directamente en el CSV
#     for team_id in range(3500):  # Desde 0 a 3500
#         team_data = fetch_team_data(team_id)
#         if team_data:
#             writer.writerow(team_data)
#         time.sleep(0.01)  # Pausa de 0.01 segundos para evitar limitaciones de tasa

#         print(f"Processed team ID: {team_id}")  # Imprimir el ID del equipo procesado para seguimiento

# Equipos de primera
team_ids = [
    2817, 2829, 2885, 6577, 33779, 24264, 2836, 2825,
    2824, 2816, 2819, 2828, 2859, 2833, 2820, 2826, 2821,
    2818, 4488, 2858
]

with open('teams.csv', 'w', newline='') as file:
    fieldnames = ['id', 'name', 'country', 'sport', 'primary_tournament', 'gender']  # Añadir 'gender' a los nombres de los campos
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()

    # Realizar las solicitudes y escribir cada equipo directamente en el CSV
    for team_id in team_ids:  # Desde 0 a 3500
        team_data = fetch_team_data(team_id)
        if team_data:
            writer.writerow(team_data)
        time.sleep(0.01)  # Pausa de 0.01 segundos para evitar limitaciones de tasa

        print(f"Processed team ID: {team_id}")  # Imprimir el ID del equipo procesado para seguimiento
# Out:
# Processed team ID: 2817
# Processed team ID: 2829
# Processed team ID: 2885
# Processed team ID: 6577
# Processed team ID: 33779
# Processed team ID: 24264
# Processed team ID: 2836
# Processed team ID: 2825
# Processed team ID: 2824
# Processed team ID: 2816
# Processed team ID: 2819
# Processed team ID: 2828
# Processed team ID: 2859
# Processed team ID: 2833
# Processed team ID: 2820
# Processed team ID: 2826
# Processed team ID: 2821
# Processed team ID: 2818
# Processed team ID: 4488
# Processed team ID: 2858

# %%
import pandas as pd

# Configurar la visualización para que muestre todas las columnas
pd.set_option('display.max_columns', None)
# Configurar para que no limite la cantidad de filas mostradas
pd.set_option('display.max_rows', None)
# Configurar la anchura máxima de cada columna
pd.set_option('display.max_colwidth', None)

# Cargar los datos del archivo CSV
df = pd.read_csv('teams.csv')

# Filtrar para obtener solo los equipos de España que juegan en LaLiga
spanish_laliga_teams = df[(df['country'] == 'Spain') & (df['primary_tournament'] == 'LaLiga')]

# Mostrar los equipos españoles de LaLiga como una tabla
print(spanish_laliga_teams.to_string(index=False))
# Out:
#    id             name country    sport primary_tournament gender
#  2817        Barcelona   Spain Football             LaLiga      M
#  2829      Real Madrid   Spain Football             LaLiga      M
#  2885 Deportivo Alavés   Spain Football             LaLiga      M
#  6577       Las Palmas   Spain Football             LaLiga      M
# 33779          Granada   Spain Football             LaLiga      M
# 24264        Girona FC   Spain Football             LaLiga      M
#  2836  Atlético Madrid   Spain Football             LaLiga      M
#  2825    Athletic Club   Spain Football             LaLiga      M
#  2824    Real Sociedad   Spain Football             LaLiga      M
#  2816       Real Betis   Spain Football             LaLiga      M
#  2819       Villarreal   Spain Football             LaLiga      M
#  2828         Valencia   Spain Football             LaLiga      M
#  2859           Getafe   Spain Football             LaLiga      M
#  2833          Sevilla   Spain Football             LaLiga      M
#  2820          Osasuna   Spain Football             LaLiga      M
#  2826         Mallorca   Spain Football             LaLiga      M
#  2821       Celta Vigo   Spain Football             LaLiga      M
#  2818   Rayo Vallecano   Spain Football             LaLiga      M
#  4488            Cádiz   Spain Football             LaLiga      M
#  2858          Almería   Spain Football             LaLiga      M

# %% [markdown]
# #### Clasificación

# %%
import requests
import pandas as pd

def fetch_and_display_standings(url):
    """Esta función obtiene los datos de la clasificación desde el URL dado y los muestra en forma de tabla."""
    
    # Realizar la solicitud GET a la API
    response = requests.get(url)
    data = response.json()

    # Extraer los datos de los equipos de la clasificación
    teams_data = data['standings'][0]['rows']  # Asumiendo que 'standings' contiene la clasificación deseada

    # Crear una lista para almacenar los datos de los equipos
    teams_list = []
    for team in teams_data:
        team_info = {
            'Position': team['position'],
            'Team': team['team']['name'],
            'Matches': team['matches'],
            'Wins': team['wins'],
            'Draws': team['draws'],
            'Losses': team['losses'],
            'Goals For': team['scoresFor'],
            'Goals Against': team['scoresAgainst'],
            'Points': team['points'],
            'Promotion/Relegation': team.get('promotion', {}).get('text', 'N/A')  # Manera segura de manejar promociones no disponibles
        }
        teams_list.append(team_info)

    # Convertir la lista en un DataFrame de pandas para una mejor visualización
    df = pd.DataFrame(teams_list)

    # Configurar pandas para mostrar la tabla completa sin truncar
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 1000)
    pd.set_option('display.colheader_justify', 'center')

    print(df)

# URL para la clasificación total de LaLiga
url_total = "http://www.sofascore.com/api/v1/unique-tournament/8/season/52376/standings/total"
# URL para la clasificación de local
url_home = "http://www.sofascore.com/api/v1/unique-tournament/8/season/52376/standings/home"
# URL para la clasificación de visitante
url_away = "http://www.sofascore.com/api/v1/unique-tournament/8/season/52376/standings/away"

# Llamar a la función para cada clasificación
print("Clasificación Total de LaLiga:")
fetch_and_display_standings(url_total)

print("\nClasificación en Casa de LaLiga:")
fetch_and_display_standings(url_home)

print("\nClasificación como Visitante de LaLiga:")
fetch_and_display_standings(url_away)
# Out:
# Clasificación Total de LaLiga:
#     Position        Team        Matches  Wins  Draws  Losses  Goals For  Goals Against  Points          Promotion/Relegation
# 0       1          Real Madrid    35      28     6       1       78           22          90                        Champions League
# 1       2            Girona FC    35      23     6       6       75           44          75                        Champions League
# 2       3            Barcelona    34      22     7       5       70           43          73                        Champions League
# 3       4      Atlético Madrid    35      22     4       9       64           39          70                        Champions League
# 4       5        Athletic Club    35      17    11       7       57           35          62                      UEFA Europa League
# 5       6           Real Betis    35      14    13       8       46           41          55                      UEFA Europa League
# 6       7        Real Sociedad    34      14    12       8       48           35          54    UEFA Conference League Qualification
# 7       8             Valencia    35      13     9      13       37           39          48                                     N/A
# 8       9           Villarreal    35      13     9      13       59           60          48                                     N/A
# 9      10               Getafe    35      10    13      12       41           48          43                                     N/A
# 10     11     Deportivo Alavés    35      11     9      15       34           40          42                                     N/A
# 11     12              Sevilla    35      10    11      14       47           49          41                                     N/A
# 12     13              Osasuna    35      11     7      17       39           53          40                                     N/A
# 13     14           Las Palmas    35      10     7      18       30           44          37                                     N/A
# 14     15             Mallorca    35       7    14      14       28           40          35                                     N/A
# 15     16       Rayo Vallecano    35       7    14      14       27           43          35                                     N/A
# 16     17           Celta Vigo    35       8    10      17       40           53          34                                     N/A
# 17     18                Cádiz    35       5    14      16       24           49          29                              Relegation
# 18     19              Granada    35       4     9      22       36           68          21                              Relegation
# 19     20              Almería    35       2    11      22       35           70          17                              Relegation
#
# Clasificación en Casa de LaLiga:
#     Position        Team        Matches  Wins  Draws  Losses  Goals For  Goals Against  Points          Promotion/Relegation
# 0       1      Atlético Madrid    18      16     1       1       41           18          49                        Champions League
# 1       2          Real Madrid    17      15     2       0       43            9          47                        Champions League
# 2       3            Girona FC    17      14     2       1       46           19          44                        Champions League
# 3       4            Barcelona    17      13     1       3       38           21          40                        Champions League
# 4       5        Athletic Club    18      11     6       1       40           18          39                      UEFA Europa League
# 5       6           Real Betis    18       9     7       2       27           17          34                      UEFA Europa League
# 6       7             Valencia    18       8     6       4       19           11          30                                     N/A
# 7       8               Getafe    17       8     5       4       19           17          29                                     N/A
# 8       9     Deportivo Alavés    18       8     4       6       22           19          28                                     N/A
# 9      10        Real Sociedad    17       7     6       4       25           18          27    UEFA Conference League Qualification
# 10     11           Villarreal    18       7     4       7       32           28          25                                     N/A
# 11     12             Mallorca    18       6     7       5       15           14          25                                     N/A
# 12     13              Sevilla    17       6     5       6       26           24          23                                     N/A
# 13     14                Cádiz    18       5     8       5       16           19          23                              Relegation
# 14     15           Las Palmas    17       6     4       7       17           17          22                                     N/A
# 15     16              Osasuna    17       6     3       8       17           24          21                                     N/A
# 16     17           Celta Vigo    17       5     5       7       17           20          20                                     N/A
# 17     18              Granada    18       4     6       8       23           30          18                              Relegation
# 18     19       Rayo Vallecano    17       3     8       6       16           24          17                                     N/A
# 19     20              Almería    17       0     8       9       16           33           8                              Relegation
#
# Clasificación como Visitante de LaLiga:
#     Position        Team        Matches  Wins  Draws  Losses  Goals For  Goals Against  Points          Promotion/Relegation
# 0       1          Real Madrid    18      13     4       1       35           13          43                        Champions League
# 1       2            Barcelona    17       9     6       2       32           22          33                        Champions League
# 2       3            Girona FC    18       9     4       5       29           25          31                        Champions League
# 3       4        Real Sociedad    17       7     6       4       23           17          27    UEFA Conference League Qualification
# 4       5        Athletic Club    17       6     5       6       17           17          23                      UEFA Europa League
# 5       6           Villarreal    17       6     5       6       27           32          23                                     N/A
# 6       7      Atlético Madrid    17       6     3       8       23           21          21                        Champions League
# 7       8           Real Betis    17       5     6       6       19           24          21                      UEFA Europa League
# 8       9              Osasuna    18       5     4       9       22           29          19                                     N/A
# 9      10              Sevilla    18       4     6       8       21           25          18                                     N/A
# 10     11       Rayo Vallecano    18       4     6       8       11           19          18                                     N/A
# 11     12             Valencia    17       5     3       9       18           28          18                                     N/A
# 12     13           Las Palmas    18       4     3      11       13           27          15                                     N/A
# 13     14               Getafe    18       2     8       8       22           31          14                                     N/A
# 14     15     Deportivo Alavés    17       3     5       9       12           21          14                                     N/A
# 15     16           Celta Vigo    18       3     5      10       23           33          14                                     N/A
# 16     17             Mallorca    17       1     7       9       13           26          10                                     N/A
# 17     18              Almería    18       2     3      13       19           37           9                              Relegation
# 18     19                Cádiz    17       0     6      11        8           30           6                              Relegation
# 19     20              Granada    17       0     3      14       13           38           3                              Relegation

# %% [markdown]
# #### Mejores jugadores por categorías
#
# EXtrae mal el dato relevante de cada categoría

# %%
import requests
import pandas as pd

def fetch_and_display_top_players(url, category):
    response = requests.get(url)
    data = response.json()
    # print(data)

    # Verificar si la categoría específica existe en los datos
    if category in data['topPlayers']:
        players_data = data['topPlayers'][category]

        players_list = []
        for player in players_data:
            # Extraer la información relevante del jugador y su equipo
            player_details = {
                'Name': player['player']['name'],
                'Position': player['player']['position'],
                'Team': player['team']['name'],
                category: player['statistics'].get(category, 'N/A'),
                'Appearances': player['statistics'].get('appearances', 'N/A')
            }
            players_list.append(player_details)

        # Crear DataFrame a partir de la lista de jugadores
        df = pd.DataFrame(players_list)
        return df
    else:
        print(f"No data available for category: {category}")
        return pd.DataFrame()  # Retorna un DataFrame vacío si no hay datos para esa categoría

# URL base que contiene las estadísticas generales de los jugadores
url_base = "http://www.sofascore.com/api/v1/unique-tournament/8/season/52376/top-players/overall"

# Lista de categorías de estadísticas para procesar
categories = [
    'rating', 'goals', 'expectedGoals', 'assists', 'expectedAssists', 'goalsAssistsSum',
    'penaltyGoals', 'freeKickGoal', 'scoringFrequency', 'totalShots', 'shotsOnTarget',
    'bigChancesMissed', 'bigChancesCreated', 'accuratePasses', 'keyPasses', 'accurateLongBalls',
    'successfulDribbles', 'penaltyWon', 'tackles', 'interceptions', 'clearances', 'possessionLost',
    'yellowCards', 'redCards', 'saves', 'goalsPrevented', 'mostConceded', 'leastConceded', 'cleanSheet'
]

# categories = [
#     'goals'
# ]

# Mostrar la información de cada categoría
for category in categories:
    print(f"\n--- {category.upper()} ---")
    df_category = fetch_and_display_top_players(url_base, category)
    if not df_category.empty:
        print(df_category)
# Out:
# --- RATING ---
#             Name          Position       Team         rating   Appearances
# 0         Jude Bellingham     M         Real Madrid  8.000000      26
# 1              Toni Kroos     M         Real Madrid  7.609677      31
# 2                    Isco     M          Real Betis  7.557143      28
# 3              Iago Aspas     F          Celta Vigo  7.550000      32
# 4          İlkay Gündoğan     M           Barcelona  7.478788      33
# 5            Aleix García     M           Girona FC  7.432353      34
# 6           Takefusa Kubo     M       Real Sociedad  7.426923      27
# 7       Antoine Griezmann     F     Atlético Madrid  7.420000      30
# 8       Federico Valverde     M         Real Madrid  7.388235      34
# 9          Iñaki Williams     M       Athletic Club  7.371875      32
# 10           Sergio Ramos     D             Sevilla  7.336000      25
# 11          Gerard Moreno     F          Villarreal  7.310345      29
# 12                Rodrygo     F         Real Madrid  7.306452      31
# 13           João Cancelo     D           Barcelona  7.271429      28
# 14        Alejandro Baena     M          Villarreal  7.259375      32
# 15                 Pepelu     M            Valencia  7.240000      35
# 16        Daniel Carvajal     D         Real Madrid  7.240000      26
# 17                  Sávio     M           Girona FC  7.235294      34
# 18     Robert Lewandowski     F           Barcelona  7.232258      31
# 19        Filip Jörgensen     G          Villarreal  7.229412      34
# 20        Paulo Gazzaniga     G           Girona FC  7.217143      35
# 21           Ante Budimir     F             Osasuna  7.216129      31
# 22           Brais Méndez     M       Real Sociedad  7.200000      28
# 23         Gorka Guruzeta     F       Athletic Club  7.190625      32
# 24       Jeremías Ledesma     G               Cádiz  7.190625      32
# 25    Aurélien Tchouaméni     M         Real Madrid  7.181481      27
# 26           Mikel Merino     M       Real Sociedad  7.179310      29
# 27          Álvaro Valles     G          Las Palmas  7.170588      34
# 28            Dani Parejo     M          Villarreal  7.163333      30
# 29         Antonio Raíllo     D            Mallorca  7.160870      23
# 30           Artem Dovbyk     F           Girona FC  7.148485      33
# 31      Alexander Sørloth     F          Villarreal  7.141935      31
# 32           Jules Koundé     D           Barcelona  7.141935      31
# 33         Vicente Guaita     G          Celta Vigo  7.138462      26
# 34            David Soria     G              Getafe  7.137143      35
# 35       Kirian Rodríguez     M          Las Palmas  7.135294      34
# 36              Rui Silva     G          Real Betis  7.126923      26
# 37        Mason Greenwood     M              Getafe  7.126667      30
# 38            Eric García     D           Girona FC  7.117241      29
# 39          Sergi Cardona     D          Las Palmas  7.115152      33
# 40   Giorgi Mamardashvili     G            Valencia  7.108824      34
# 41          Nico Williams     M       Athletic Club  7.106897      29
# 42        Lucas Robertone     M             Almería  7.106667      30
# 43  Marc-André ter Stegen     G           Barcelona  7.104167      24
# 44       Predrag Rajković     G            Mallorca  7.100000      34
# 45         Yangel Herrera     M           Girona FC  7.096154      26
# 46             Unai Simón     G       Athletic Club  7.094118      34
# 47             Luis Milla     M              Getafe  7.091304      24
# 48            Ayoze Pérez     M          Real Betis  7.085714      28
# 49          Lucas Ocampos     M             Sevilla  7.081250      32
#
# --- GOALS ---
#             Name         Position        Team        goals  Appearances
# 0           Artem Dovbyk     F            Girona FC   20        33
# 1      Alexander Sørloth     F           Villarreal   19        31
# 2        Jude Bellingham     M          Real Madrid   18        26
# 3     Robert Lewandowski     F            Barcelona   17        31
# 4           Ante Budimir     F              Osasuna   16        31
# 5          Borja Mayoral     F               Getafe   15        27
# 6      Youssef En-Nesyri     F              Sevilla   15        30
# 7         Gorka Guruzeta     F        Athletic Club   14        32
# 8          Álvaro Morata     F      Atlético Madrid   14        30
# 9      Antoine Griezmann     F      Atlético Madrid   13        30
# 10       Vinícius Júnior     F          Real Madrid   13        24
# 11             Hugo Duro     F             Valencia   13        35
# 12        Iñaki Williams     M        Athletic Club   12        32
# 13  Jørgen Strand Larsen     F           Celta Vigo   12        34
# 14           Myrto Uzuni     F              Granada   11        34
# 15         Gerard Moreno     F           Villarreal   10        29
# 16               Rodrygo     F          Real Madrid   10        31
# 17          Willian José     F           Real Betis   10        31
# 18          Ángel Correa     F      Atlético Madrid    9        29
# 19       Mikel Oyarzabal     F        Real Sociedad    9        29
# 20                Joselu     F          Real Madrid    9        33
# 21      Samuel Omorodion     F     Deportivo Alavés    9        32
# 22                  Isco     M           Real Betis    8        28
# 23            Iago Aspas     F           Celta Vigo    8        32
# 24                 Sávio     M            Girona FC    8        34
# 25           Brahim Díaz     M          Real Madrid    8        30
# 26       Mason Greenwood     M               Getafe    8        30
# 27           Ayoze Pérez     M           Real Betis    8        28
# 28      Cristhian Stuani     F            Girona FC    8        29
# 29         Takefusa Kubo     M        Real Sociedad    7        27
# 30            João Félix     F            Barcelona    7        27
# 31         Ferran Torres     F            Barcelona    7        26
# 32                 Portu     F            Girona FC    7        33
# 33                Pepelu     M             Valencia    6        35
# 34      Kirian Rodríguez     M           Las Palmas    6        34
# 35      Viktor Tsygankov     M            Girona FC    6        27
# 36          Vedat Muriqi     F             Mallorca    6        27
# 37       Marcos Llorente     M      Atlético Madrid    6        34
# 38        Sergio Arribas     M              Almería    6        32
# 39        Bryan Zaragoza     M              Granada    6        21
# 40         Álvaro García     M       Rayo Vallecano    6        29
# 41        Álex Berenguer     M        Athletic Club    6        32
# 42         Léo Baptistão     F              Almería    6        29
# 43           Abdón Prats     F             Mallorca    6        31
# 44   Anastasios Douvikas     F           Celta Vigo    6        29
# 45     José Luis Morales     F           Villarreal    6        27
# 46        İlkay Gündoğan     M            Barcelona    5        33
# 47              Raphinha     F            Barcelona    5        26
# 48        Yangel Herrera     M            Girona FC    5        26
# 49            Luis Rioja     M     Deportivo Alavés    5        35
#
# --- EXPECTEDGOALS ---
#             Name         Position        Team        expectedGoals  Appearances
# 0           Artem Dovbyk     F            Girona FC     20.3924         33
# 1     Robert Lewandowski     F            Barcelona     17.2691         31
# 2           Ante Budimir     F              Osasuna     13.8105         31
# 3   Jørgen Strand Larsen     F           Celta Vigo     13.4721         34
# 4          Álvaro Morata     F      Atlético Madrid     12.9089         30
# 5            Myrto Uzuni     F              Granada     12.9065         34
# 6        Vinícius Júnior     F          Real Madrid     12.1123         24
# 7          Borja Mayoral     F               Getafe     11.8635         27
# 8         Gorka Guruzeta     F        Athletic Club     11.7074         32
# 9                 Joselu     F          Real Madrid     11.6849         33
# 10             Hugo Duro     F             Valencia     11.4851         35
# 11     Antoine Griezmann     F      Atlético Madrid     11.1656         30
# 12     Alexander Sørloth     F           Villarreal     11.0991         31
# 13       Jude Bellingham     M          Real Madrid     10.8044         26
# 14               Rodrygo     F          Real Madrid     10.7207         31
# 15            Iago Aspas     F           Celta Vigo     10.5441         32
# 16      Samuel Omorodion     F     Deportivo Alavés     10.4157         32
# 17     Youssef En-Nesyri     F              Sevilla     10.1232         30
# 18         Gerard Moreno     F           Villarreal      9.6832         29
# 19          Vedat Muriqi     F             Mallorca      9.0247         27
# 20        Iñaki Williams     M        Athletic Club      8.8343         32
# 21       Mikel Oyarzabal     F        Real Sociedad      8.8274         29
# 22           Chris Ramos     F                Cádiz      8.6571         35
# 23      Cristhian Stuani     F            Girona FC      8.5191         29
# 24                  Isco     M           Real Betis      8.3004         28
# 25            João Félix     F            Barcelona      7.9856         27
# 26       Alejandro Baena     M           Villarreal      7.9396         32
# 27       Mason Greenwood     M               Getafe      7.7490         30
# 28          Ángel Correa     F      Atlético Madrid      7.6817         29
# 29            Cyle Larin     F             Mallorca      7.6732         32
# 30          Isaac Romero     F              Sevilla      7.2880         14
# 31        Sergio Arribas     M              Almería      6.9595         32
# 32           Kike García     F     Deportivo Alavés      6.9420         32
# 33        İlkay Gündoğan     M            Barcelona      6.6575         33
# 34          Fermín López     M            Barcelona      6.5653         27
# 35                Pepelu     M             Valencia      6.4590         35
# 36           Ayoze Pérez     M           Real Betis      6.3958         28
# 37              Raphinha     F            Barcelona      6.3745         26
# 38          Oihan Sancet     M        Athletic Club      6.2956         30
# 39            Luis Rioja     M     Deportivo Alavés      5.9187         35
# 40         Memphis Depay     F      Atlético Madrid      5.7623         21
# 41           Brahim Díaz     M          Real Madrid      5.6252         30
# 42    Luis Javier Suárez     F              Almería      5.5215         12
# 43    Nemanja Maksimović     M               Getafe      5.5098         34
# 44          Willian José     F           Real Betis      5.4987         31
# 45         Ferran Torres     F            Barcelona      5.3525         26
# 46            Jaime Mata     M               Getafe      5.3261         32
# 47           Isi Palazón     M       Rayo Vallecano      5.1674         34
# 48                 Sávio     M            Girona FC      5.1602         34
# 49         Lucas Ocampos     M              Sevilla      5.1157         32
#
# --- ASSISTS ---
#            Name        Position        Team        assists  Appearances
# 0      Alejandro Baena     M           Villarreal    13         32
# 1        Nico Williams     M        Athletic Club    10         29
# 2           Iago Aspas     F           Celta Vigo     9         32
# 3             Raphinha     F            Barcelona     9         26
# 4                Sávio     M            Girona FC     9         34
# 5   Robert Lewandowski     F            Barcelona     8         31
# 6            Yan Couto     D            Girona FC     8         33
# 7           Toni Kroos     M          Real Madrid     7         31
# 8       İlkay Gündoğan     M            Barcelona     7         33
# 9    Federico Valverde     M          Real Madrid     7         34
# 10        Artem Dovbyk     F            Girona FC     7         33
# 11          Diego Rico     D               Getafe     7         30
# 12        Aleix García     M            Girona FC     6         34
# 13   Antoine Griezmann     F      Atlético Madrid     6         30
# 14         Luka Modrić     M          Real Madrid     6         30
# 15        Brais Méndez     M        Real Sociedad     6         28
# 16   Alexander Sørloth     F           Villarreal     6         31
# 17     Mason Greenwood     M               Getafe     6         30
# 18    Miguel Gutiérrez     D            Girona FC     6         33
# 19         Diego Lopez     M             Valencia     6         33
# 20                Isco     M           Real Betis     5         28
# 21             Rodrygo     F          Real Madrid     5         31
# 22     Vinícius Júnior     F          Real Madrid     5         24
# 23      Gorka Guruzeta     F        Athletic Club     5         32
# 24         Dani Parejo     M           Villarreal     5         30
# 25     Lucas Robertone     M              Almería     5         30
# 26    Viktor Tsygankov     M            Girona FC     5         27
# 27        Willian José     F           Real Betis     5         31
# 28        Sergi Darder     M             Mallorca     5         33
# 29         Fran García     D          Real Madrid     5         24
# 30         Saúl Ñíguez     M      Atlético Madrid     5         32
# 31        Oihan Sancet     M        Athletic Club     5         30
# 32    Rodrigo Riquelme     M      Atlético Madrid     5         31
# 33         Jesús Areso     D              Osasuna     5         34
# 34               Portu     F            Girona FC     5         33
# 35      Manuel Sánchez     D           Celta Vigo     5         25
# 36     Largie Ramazani     F              Almería     5         29
# 37     Jude Bellingham     M          Real Madrid     4         26
# 38       Gerard Moreno     F           Villarreal     4         29
# 39        Lamine Yamal     F            Barcelona     4         33
# 40     Rodrigo de Paul     M      Atlético Madrid     4         31
# 41       Lucas Vázquez     D          Real Madrid     4         27
# 42         Brahim Díaz     M          Real Madrid     4         30
# 43                Koke     M      Atlético Madrid     4         32
# 44                Suso     M              Sevilla     4         28
# 45     Óscar de Marcos     D        Athletic Club     4         27
# 46          Luis Rioja     M     Deportivo Alavés     4         35
# 47      Carlos Vicente     M     Deportivo Alavés     4         16
# 48       Adrià Pedrosa     D              Sevilla     4         28
# 49          Jon Guridi     M     Deportivo Alavés     4         33
#
# --- EXPECTEDASSISTS ---
#           Name        Position        Team        expectedAssists  Appearances
# 0      İlkay Gündoğan     M            Barcelona     9.511832          33
# 1     Alejandro Baena     M           Villarreal     9.184151          32
# 2          Iago Aspas     F           Celta Vigo     8.993427          32
# 3               Sávio     M            Girona FC     8.768866          34
# 4       Nico Williams     M        Athletic Club     7.372041          29
# 5    Miguel Gutiérrez     D            Girona FC     6.455756          33
# 6                Isco     M           Real Betis     6.352063          28
# 7        João Cancelo     D            Barcelona     6.048841          28
# 8      Óscar Mingueza     D           Celta Vigo     5.855130          35
# 9       Takefusa Kubo     M        Real Sociedad     5.801847          27
# 10       Lamine Yamal     F            Barcelona     5.780314          33
# 11     Iñaki Williams     M        Athletic Club     5.726260          32
# 12  Antoine Griezmann     F      Atlético Madrid     5.587648          30
# 13         Toni Kroos     M          Real Madrid     5.547198          31
# 14    Rodrigo de Paul     M      Atlético Madrid     5.527929          31
# 15       Aleix García     M            Girona FC     5.491413          34
# 16   Viktor Tsygankov     M            Girona FC     4.964797          27
# 17           Raphinha     F            Barcelona     4.923113          26
# 18    Frenkie de Jong     M            Barcelona     4.879607          20
# 19               Suso     M              Sevilla     4.723455          28
# 20     Dani Rodríguez     M             Mallorca     4.656970          33
# 21             Pepelu     M             Valencia     4.452780          35
# 22        Luka Modrić     M          Real Madrid     4.450716          30
# 23       Sergi Darder     M             Mallorca     4.446931          33
# 24        Brahim Díaz     M          Real Madrid     4.414796          30
# 25      Gerard Moreno     F           Villarreal     4.309394          29
# 26       Brais Méndez     M        Real Sociedad     4.244974          28
# 27     Bryan Zaragoza     M              Granada     4.210029          21
# 28         Luis Rioja     M     Deportivo Alavés     4.143379          35
# 29       Ivan Rakitić     M              Sevilla     4.091294          18
# 30        Dani Parejo     M           Villarreal     3.910333          30
# 31    Mason Greenwood     M               Getafe     3.885956          30
# 32          Yan Couto     D            Girona FC     3.867255          33
# 33      Lucas Ocampos     M              Sevilla     3.716714          32
# 34    Marcos Llorente     M      Atlético Madrid     3.694134          34
# 35     Jonathan Bamba     M           Celta Vigo     3.686479          25
# 36    Jude Bellingham     M          Real Madrid     3.641917          26
# 37              Pedri     M            Barcelona     3.624772          20
# 38      Gerard Gumbau     M              Granada     3.605624          32
# 39   Rodrigo Riquelme     M      Atlético Madrid     3.516805          31
# 40      Sergi Cardona     D           Las Palmas     3.511117          33
# 41     Adrián Embarba     M              Almería     3.424042          33
# 42         Diego Rico     D               Getafe     3.412305          30
# 43       Rubén García     M              Osasuna     3.387238          28
# 44            Rodrygo     F          Real Madrid     3.379329          31
# 45    Vinícius Júnior     F          Real Madrid     3.331009          24
# 46  Federico Valverde     M          Real Madrid     3.273799          34
# 47    Óscar de Marcos     D        Athletic Club     3.199661          27
# 48       Ángel Correa     F      Atlético Madrid     3.170570          29
# 49       Artem Dovbyk     F            Girona FC     3.135181          33
#
# --- GOALSASSISTSSUM ---
#             Name         Position        Team        goalsAssistsSum  Appearances
# 0           Artem Dovbyk     F            Girona FC        27             33
# 1      Alexander Sørloth     F           Villarreal        25             31
# 2     Robert Lewandowski     F            Barcelona        25             31
# 3        Jude Bellingham     M          Real Madrid        22             26
# 4         Gorka Guruzeta     F        Athletic Club        19             32
# 5      Antoine Griezmann     F      Atlético Madrid        19             30
# 6           Ante Budimir     F              Osasuna        18             31
# 7        Vinícius Júnior     F          Real Madrid        18             24
# 8      Youssef En-Nesyri     F              Sevilla        17             30
# 9             Iago Aspas     F           Celta Vigo        17             32
# 10                 Sávio     M            Girona FC        17             34
# 11         Borja Mayoral     F               Getafe        16             27
# 12         Álvaro Morata     F      Atlético Madrid        16             30
# 13             Hugo Duro     F             Valencia        15             35
# 14        Iñaki Williams     M        Athletic Club        15             32
# 15               Rodrygo     F          Real Madrid        15             31
# 16          Willian José     F           Real Betis        15             31
# 17       Alejandro Baena     M           Villarreal        15             32
# 18  Jørgen Strand Larsen     F           Celta Vigo        14             34
# 19         Gerard Moreno     F           Villarreal        14             29
# 20       Mason Greenwood     M               Getafe        14             30
# 21              Raphinha     F            Barcelona        14             26
# 22         Nico Williams     M        Athletic Club        14             29
# 23                  Isco     M           Real Betis        13             28
# 24           Myrto Uzuni     F              Granada        12             34
# 25           Brahim Díaz     M          Real Madrid        12             30
# 26                 Portu     F            Girona FC        12             33
# 27        İlkay Gündoğan     M            Barcelona        12             33
# 28          Ángel Correa     F      Atlético Madrid        11             29
# 29       Mikel Oyarzabal     F        Real Sociedad        11             29
# 30                Joselu     F          Real Madrid        11             33
# 31      Viktor Tsygankov     M            Girona FC        11             27
# 32      Samuel Omorodion     F     Deportivo Alavés        10             32
# 33      Cristhian Stuani     F            Girona FC        10             29
# 34         Takefusa Kubo     M        Real Sociedad        10             27
# 35            João Félix     F            Barcelona        10             27
# 36          Brais Méndez     M        Real Sociedad        10             28
# 37           Ayoze Pérez     M           Real Betis         9             28
# 38         Ferran Torres     F            Barcelona         9             26
# 39       Marcos Llorente     M      Atlético Madrid         9             34
# 40        Sergio Arribas     M              Almería         9             32
# 41            Luis Rioja     M     Deportivo Alavés         9             35
# 42          Oihan Sancet     M        Athletic Club         9             30
# 43          Aleix García     M            Girona FC         9             34
# 44           Diego Lopez     M             Valencia         9             33
# 45             Yan Couto     D            Girona FC         9             33
# 46      Kirian Rodríguez     M           Las Palmas         8             34
# 47          Vedat Muriqi     F             Mallorca         8             27
# 48        Bryan Zaragoza     M              Granada         8             21
# 49        Álex Berenguer     M        Athletic Club         8             32
#
# --- PENALTYGOALS ---
#            Name        Position        Team        penaltyGoals  Appearances
# 0               Pepelu     M             Valencia        6           35
# 1         Artem Dovbyk     F            Girona FC        5           33
# 2    Antoine Griezmann     F      Atlético Madrid        4           30
# 3   Robert Lewandowski     F            Barcelona        4           31
# 4        Borja Mayoral     F               Getafe        4           27
# 5          Myrto Uzuni     F              Granada        4           34
# 6          Dani Parejo     M           Villarreal        3           30
# 7         Ante Budimir     F              Osasuna        3           31
# 8           Luis Rioja     M     Deportivo Alavés        3           35
# 9                 Isco     M           Real Betis        2           28
# 10      Jonathan Viera     M              Almería        2           19
# 11       Rubén Alcaraz     M                Cádiz        2           33
# 12         Isi Palazón     M       Rayo Vallecano        2           34
# 13     Mikel Oyarzabal     F        Real Sociedad        2           29
# 14         Mikel Vesga     M        Athletic Club        2           26
# 15       Gerard Moreno     F           Villarreal        2           29
# 16     Mason Greenwood     M               Getafe        2           30
# 17          Iago Aspas     F           Celta Vigo        2           32
# 18     Jude Bellingham     M          Real Madrid        1           26
# 19     Vinícius Júnior     F          Real Madrid        1           24
# 20       Lucas Ocampos     M              Sevilla        1           32
# 21        Ángel Correa     F      Atlético Madrid        1           29
# 22  Luis Javier Suárez     F              Almería        1           12
# 23      Bryan Zaragoza     M              Granada        1           21
# 24   Youssef En-Nesyri     F              Sevilla        1           30
# 25      Adrián Embarba     M              Almería        1           33
# 26      Álex Berenguer     M        Athletic Club        1           32
# 27          Aimar Oroz     M              Osasuna        1           30
# 28        Marc Cardona     F           Las Palmas        1           23
# 29       Raúl de Tomás     F       Rayo Vallecano        1           24
# 30         Randy Nteka     F       Rayo Vallecano        1           15
# 31    Carlos Fernández     F        Real Sociedad        1           10
# 32                Bebé     M       Rayo Vallecano        1           18
# 33       Darwin Machís     F                Cádiz        1           21
# 34      Radamel Falcao     F       Rayo Vallecano        1           20
# 35         André Silva     F        Real Sociedad        1           17
# 36      İlkay Gündoğan     M            Barcelona        1           33
# 37        Vedat Muriqi     F             Mallorca        1           27
# 38              Joselu     F          Real Madrid        0           33
# 39             Rodrygo     F          Real Madrid        0           31
# 40     Alejandro Baena     M           Villarreal        0           32
# 41      Gorka Guruzeta     F        Athletic Club        0           32
# 42       Álvaro Morata     F      Atlético Madrid        0           30
# 43      Sandro Ramírez     F           Las Palmas        0           24
# 44        Oihan Sancet     M        Athletic Club        0           30
# 45          Ianis Hagi     M     Deportivo Alavés        0           19
# 46         Kike García     F     Deportivo Alavés        0           32
# 47    Munir El Haddadi     F           Las Palmas        0           35
# 48     Antonio Puertas     M              Granada        0           26
#
# --- FREEKICKGOAL ---
#            Name        Position        Team        freeKickGoal  Appearances
# 0        Ferran Torres     F            Barcelona        1           26
# 1   Robert Lewandowski     F            Barcelona        1           31
# 2         Willian José     F           Real Betis        1           31
# 3        Rubén Alcaraz     M                Cádiz        1           33
# 4            Saul Coco     D           Las Palmas        1           27
# 5         Brais Méndez     M        Real Sociedad        1           28
# 6      Florian Lejeune     D       Rayo Vallecano        1           34
# 7               Pepelu     M             Valencia        0           35
# 8       Adrián Embarba     M              Almería        0           33
# 9           Toni Kroos     M          Real Madrid        0           31
# 10            Raphinha     F            Barcelona        0           26
# 11        Aleix García     M            Girona FC        0           34
# 12       Gerard Gumbau     M              Granada        0           32
# 13          Iago Aspas     F           Celta Vigo        0           32
# 14         David Alaba     D          Real Madrid        0           14
# 15    Javier Hernández     D                Cádiz        0           27
# 16      İlkay Gündoğan     M            Barcelona        0           33
# 17     Alejandro Baena     M           Villarreal        0           32
# 18         Nabil Fekir     M           Real Betis        0           17
# 19  José Manuel Arnáiz     F              Osasuna        0           24
# 20                Isco     M           Real Betis        0           28
# 21        Sergio Ramos     D              Sevilla        0           25
# 22          Luis Rioja     M     Deportivo Alavés        0           35
# 23      Sandro Ramírez     F           Las Palmas        0           24
# 24      Nemanja Gudelj     D              Sevilla        0           21
# 25          Ianis Hagi     M     Deportivo Alavés        0           19
# 26     Arsen Zakharyan     M        Real Sociedad        0           25
# 27        Ivan Rakitić     M              Sevilla        0           18
# 28   Antoine Griezmann     F      Atlético Madrid        0           30
# 29             Rodrygo     F          Real Madrid        0           31
# 30      Gorka Guruzeta     F        Athletic Club        0           32
# 31      Jonathan Viera     M              Almería        0           19
# 32     Mason Greenwood     M               Getafe        0           30
# 33     Lucas Robertone     M              Almería        0           30
# 34        Rubén García     M              Osasuna        0           28
# 35         Isi Palazón     M       Rayo Vallecano        0           34
# 36     Mikel Oyarzabal     F        Real Sociedad        0           29
# 37     Óscar Rodríguez     M               Getafe        0           22
# 38          Unai López     M       Rayo Vallecano        0           32
# 39       Memphis Depay     F      Atlético Madrid        0           21
# 40       Omar Alderete     D               Getafe        0           28
# 41       Raúl de Tomás     F       Rayo Vallecano        0           24
# 42         Lucas Pires     D                Cádiz        0           27
# 43                Bebé     M       Rayo Vallecano        0           18
# 44       Takefusa Kubo     M        Real Sociedad        0           27
# 45         Dani Parejo     M           Villarreal        0           30
# 46    Kirian Rodríguez     M           Las Palmas        0           34
# 47    Viktor Tsygankov     M            Girona FC        0           27
# 48        Renato Tapia     M           Celta Vigo        0           19
# 49           Hugo Duro     F             Valencia        0           35
#
# --- SCORINGFREQUENCY ---
#             Name         Position        Team        scoringFrequency  Appearances
# 0       Cristhian Stuani     F            Girona FC      95.250000         29
# 1           Artem Dovbyk     F            Girona FC     117.300000         33
# 2        Jude Bellingham     M          Real Madrid     119.111111         26
# 3                   Bebé     M       Rayo Vallecano     120.500000         18
# 4      Alexander Sørloth     F           Villarreal     120.736842         31
# 5        Vinícius Júnior     F          Real Madrid     130.153846         24
# 6          Álvaro Morata     F      Atlético Madrid     132.071429         30
# 7    Anastasios Douvikas     F           Celta Vigo     139.333333         29
# 8          Borja Mayoral     F               Getafe     144.133333         27
# 9     Robert Lewandowski     F            Barcelona     145.411765         31
# 10          Ángel Correa     F      Atlético Madrid     148.888889         29
# 11          Ante Budimir     F              Osasuna     149.062500         31
# 12     Youssef En-Nesyri     F              Sevilla     153.666667         30
# 13         Ferran Torres     F            Barcelona     156.857143         26
# 14        Gorka Guruzeta     F        Athletic Club     160.000000         32
# 15     José Luis Morales     F           Villarreal     164.166667         27
# 16                 Portu     F            Girona FC     171.000000         33
# 17         Memphis Depay     F      Atlético Madrid     172.200000         21
# 18                Joselu     F          Real Madrid     176.666667         33
# 19     Antoine Griezmann     F      Atlético Madrid     183.615385         30
# 20          Willian José     F           Real Betis     184.200000         31
# 21        Dodi Lukebakio     F              Sevilla     185.000000         20
# 22           Brahim Díaz     M          Real Madrid     189.250000         30
# 23           Abdón Prats     F             Mallorca     191.000000         31
# 24         Darwin Machís     F                Cádiz     199.750000         21
# 25      Samuel Omorodion     F     Deportivo Alavés     207.000000         32
# 26            João Félix     F            Barcelona     210.142857         27
# 27       Mikel Oyarzabal     F        Real Sociedad     215.555556         29
# 28         Gerard Moreno     F           Villarreal     215.600000         29
# 29               Rodrygo     F          Real Madrid     218.600000         31
# 30           Myrto Uzuni     F              Granada     223.545455         34
# 31          Marc Cardona     F           Las Palmas     223.666667         23
# 32             Hugo Duro     F             Valencia     225.846154         35
# 33  Jørgen Strand Larsen     F           Celta Vigo     226.916667         34
# 34        Iñaki Williams     M        Athletic Club     228.750000         32
# 35        Álex Berenguer     M        Athletic Club     231.000000         32
# 36          Fermín López     M            Barcelona     240.800000         27
# 37              Raphinha     F            Barcelona     245.400000         26
# 38      Valery Fernández     D            Girona FC     248.000000         25
# 39           Ayoze Pérez     M           Real Betis     254.625000         28
# 40        Anthony Lozano     F              Almería     263.000000         17
# 41        Bryan Zaragoza     M              Granada     273.333333         21
# 42         Takefusa Kubo     M        Real Sociedad     279.285714         27
# 43       Roman Yaremchuk     F             Valencia     280.333333         23
# 44                  Isco     M           Real Betis     287.375000         28
# 45         Léo Baptistão     F              Almería     291.833333         29
# 46           Raúl García     F              Osasuna     292.500000         32
# 47       Mason Greenwood     M               Getafe     299.625000         30
# 48      Viktor Tsygankov     M            Girona FC     310.000000         27
# 49            Iago Aspas     F           Celta Vigo     313.125000         32
#
# --- TOTALSHOTS ---
#             Name         Position        Team        totalShots  Appearances
# 0        Vinícius Júnior     F          Real Madrid      70          24
# 1        Mason Greenwood     M               Getafe      87          30
# 2         Iñaki Williams     M        Athletic Club      90          32
# 3     Robert Lewandowski     F            Barcelona      87          31
# 4                Rodrygo     F          Real Madrid      79          31
# 5      Antoine Griezmann     F      Atlético Madrid      72          30
# 6           Ante Budimir     F              Osasuna      74          31
# 7             Iago Aspas     F           Celta Vigo      75          32
# 8           Artem Dovbyk     F            Girona FC      76          33
# 9   Jørgen Strand Larsen     F           Celta Vigo      78          34
# 10                  Isco     M           Real Betis      64          28
# 11     Youssef En-Nesyri     F              Sevilla      67          30
# 12       Jude Bellingham     M          Real Madrid      58          26
# 13     Alexander Sørloth     F           Villarreal      68          31
# 14       Alejandro Baena     M           Villarreal      70          32
# 15         Gerard Moreno     F           Villarreal      63          29
# 16         Álvaro Morata     F      Atlético Madrid      65          30
# 17          Vedat Muriqi     F             Mallorca      58          27
# 18            João Félix     F            Barcelona      56          27
# 19          Brais Méndez     M        Real Sociedad      58          28
# 20           Ayoze Pérez     M           Real Betis      58          28
# 21        Gorka Guruzeta     F        Athletic Club      64          32
# 22           Chris Ramos     F                Cádiz      69          35
# 23              Raphinha     F            Barcelona      51          26
# 24        Sandro Ramírez     F           Las Palmas      47          24
# 25            Cyle Larin     F             Mallorca      62          32
# 26                Joselu     F          Real Madrid      62          33
# 27         Lucas Ocampos     M              Sevilla      60          32
# 28             Hugo Duro     F             Valencia      65          35
# 29           Isi Palazón     M       Rayo Vallecano      63          34
# 30           Myrto Uzuni     F              Granada      63          34
# 31      Samuel Omorodion     F     Deportivo Alavés      58          32
# 32         Memphis Depay     F      Atlético Madrid      38          21
# 33          Ivan Rakitić     M              Sevilla      32          18
# 34       Florian Lejeune     D       Rayo Vallecano      60          34
# 35            Lucas Boyé     F              Granada      49          28
# 36         Borja Mayoral     F               Getafe      47          27
# 37        Yangel Herrera     M            Girona FC      45          26
# 38        Adrián Embarba     M              Almería      57          33
# 39         Nico Williams     M        Athletic Club      50          29
# 40           Kike García     F     Deportivo Alavés      55          32
# 41        Dodi Lukebakio     F              Sevilla      33          20
# 42         Takefusa Kubo     M        Real Sociedad      44          27
# 43         Raúl de Tomás     F       Rayo Vallecano      39          24
# 44         Léo Baptistão     F              Almería      47          29
# 45        Bryan Zaragoza     M              Granada      34          21
# 46        Jonathan Bamba     M           Celta Vigo      40          25
# 47        Sergio Arribas     M              Almería      51          32
# 48           Chimy Ávila     F           Real Betis      36          23
# 49          Fermín López     M            Barcelona      42          27
#
# --- SHOTSONTARGET ---
#             Name         Position        Team        shotsOnTarget  Appearances
# 0        Vinícius Júnior     F          Real Madrid       35            24
# 1         Iñaki Williams     M        Athletic Club       42            32
# 2     Robert Lewandowski     F            Barcelona       39            31
# 3        Jude Bellingham     M          Real Madrid       32            26
# 4           Artem Dovbyk     F            Girona FC       40            33
# 5          Álvaro Morata     F      Atlético Madrid       33            30
# 6                Rodrygo     F          Real Madrid       33            31
# 7           Ante Budimir     F              Osasuna       32            31
# 8      Alexander Sørloth     F           Villarreal       32            31
# 9      Antoine Griezmann     F      Atlético Madrid       30            30
# 10         Borja Mayoral     F               Getafe       27            27
# 11  Jørgen Strand Larsen     F           Celta Vigo       33            34
# 12        Gorka Guruzeta     F        Athletic Club       31            32
# 13       Mason Greenwood     M               Getafe       29            30
# 14     Youssef En-Nesyri     F              Sevilla       29            30
# 15                  Isco     M           Real Betis       26            28
# 16        Bryan Zaragoza     M              Granada       19            21
# 17          Vedat Muriqi     F             Mallorca       24            27
# 18           Isi Palazón     M       Rayo Vallecano       29            34
# 19            João Félix     F            Barcelona       23            27
# 20                Joselu     F          Real Madrid       28            33
# 21             Hugo Duro     F             Valencia       29            35
# 22           Myrto Uzuni     F              Granada       28            34
# 23            Iago Aspas     F           Celta Vigo       26            32
# 24           Kike García     F     Deportivo Alavés       26            32
# 25           Ayoze Pérez     M           Real Betis       22            28
# 26       Alejandro Baena     M           Villarreal       25            32
# 27        Sandro Ramírez     F           Las Palmas       18            24
# 28            Cyle Larin     F             Mallorca       24            32
# 29           Chris Ramos     F                Cádiz       26            35
# 30          Willian José     F           Real Betis       23            31
# 31              Raphinha     F            Barcelona       19            26
# 32        Adrián Embarba     M              Almería       24            33
# 33         Gerard Moreno     F           Villarreal       21            29
# 34      Samuel Omorodion     F     Deportivo Alavés       23            32
# 35         Memphis Depay     F      Atlético Madrid       15            21
# 36         Takefusa Kubo     M        Real Sociedad       19            27
# 37          Fermín López     M            Barcelona       19            27
# 38        Dodi Lukebakio     F              Sevilla       14            20
# 39          Ángel Correa     F      Atlético Madrid       20            29
# 40         Lucas Ocampos     M              Sevilla       22            32
# 41       Mikel Oyarzabal     F        Real Sociedad       19            29
# 42        Yangel Herrera     M            Girona FC       17            26
# 43           Samuel Lino     F      Atlético Madrid       20            31
# 44         Léo Baptistão     F              Almería       18            29
# 45        Jonathan Bamba     M           Celta Vigo       15            25
# 46          Lamine Yamal     F            Barcelona       19            33
# 47         Nico Williams     M        Athletic Club       16            29
# 48      Cristhian Stuani     F            Girona FC       16            29
# 49           Sergi Canós     M             Valencia       13            24
#
# --- BIGCHANCESMISSED ---
#             Name         Position        Team        bigChancesMissed  Appearances
# 0          Álvaro Morata     F      Atlético Madrid         22             30
# 1           Artem Dovbyk     F            Girona FC         20             33
# 2     Robert Lewandowski     F            Barcelona         18             31
# 3           Isaac Romero     F              Sevilla         17             14
# 4        Vinícius Júnior     F          Real Madrid         16             24
# 5       Samuel Omorodion     F     Deportivo Alavés         16             32
# 6   Jørgen Strand Larsen     F           Celta Vigo         15             34
# 7      Alexander Sørloth     F           Villarreal         13             31
# 8            Kike García     F     Deportivo Alavés         13             32
# 9                 Joselu     F          Real Madrid         13             33
# 10           Chris Ramos     F                Cádiz         13             35
# 11     Youssef En-Nesyri     F              Sevilla         12             30
# 12      Cristhian Stuani     F            Girona FC         12             29
# 13                  Isco     M           Real Betis         11             28
# 14          Ante Budimir     F              Osasuna         11             31
# 15           Myrto Uzuni     F              Granada         11             34
# 16            Cyle Larin     F             Mallorca         11             32
# 17     Antoine Griezmann     F      Atlético Madrid         10             30
# 18        Iñaki Williams     M        Athletic Club         10             32
# 19               Rodrygo     F          Real Madrid         10             31
# 20              Raphinha     F            Barcelona         10             26
# 21          Vedat Muriqi     F             Mallorca         10             27
# 22             Hugo Duro     F             Valencia         10             35
# 23            Iago Aspas     F           Celta Vigo          9             32
# 24           Ayoze Pérez     M           Real Betis          9             28
# 25         Lucas Ocampos     M              Sevilla          9             32
# 26    Nemanja Maksimović     M               Getafe          9             34
# 27       Alejandro Baena     M           Villarreal          8             32
# 28        Gorka Guruzeta     F        Athletic Club          8             32
# 29          Oihan Sancet     M        Athletic Club          8             30
# 30       Mikel Oyarzabal     F        Real Sociedad          8             29
# 31       Largie Ramazani     F              Almería          8             29
# 32            Umar Sadiq     F        Real Sociedad          8             26
# 33       Jude Bellingham     M          Real Madrid          7             26
# 34         Gerard Moreno     F           Villarreal          7             29
# 35         Borja Mayoral     F               Getafe          7             27
# 36          Fermín López     M            Barcelona          7             27
# 37         Juanmi Latasa     F               Getafe          7             30
# 38           Raúl García     F              Osasuna          7             32
# 39        İlkay Gündoğan     M            Barcelona          6             33
# 40     Federico Valverde     M          Real Madrid          6             34
# 41        Yangel Herrera     M            Girona FC          6             26
# 42          Ángel Correa     F      Atlético Madrid          6             29
# 43         Ferran Torres     F            Barcelona          6             26
# 44        Dodi Lukebakio     F              Sevilla          6             20
# 45           Diego Lopez     M             Valencia          6             33
# 46         Memphis Depay     F      Atlético Madrid          6             21
# 47   Anastasios Douvikas     F           Celta Vigo          6             29
# 48        Anthony Lozano     F              Almería          6             17
# 49                 Sávio     M            Girona FC          5             34
#
# --- BIGCHANCESCREATED ---
# ...
# 32           Cyle Larin     F             Mallorca       8           32
# 33        Rubén Sobrino     M                Cádiz       8           29
# 34   José Ángel Carmona     M               Getafe       8           27
# 35      Frenkie de Jong     M            Barcelona       7           20
# 36         Sergio Ramos     D              Sevilla       7           25
# 37  Aurélien Tchouaméni     M          Real Madrid       7           27
# 38     Kirian Rodríguez     M           Las Palmas       7           34
# 39        Lucas Ocampos     M              Sevilla       7           32
# 40         Juan Miranda     D           Real Betis       7           23
# 41      Antonio Rüdiger     D          Real Madrid       7           30
# 42      Germán Pezzella     D           Real Betis       7           32
# 43           Kike Salas     D              Sevilla       7           20
# 44       Nemanja Gudelj     D              Sevilla       7           21
# 45       Gonzalo Villar     M              Granada       7           32
# 46         Jorge Cuenca     D           Villarreal       7           26
# 47        Aitor Paredes     D        Athletic Club       7           32
# 48        Ander Guevara     M     Deportivo Alavés       7           34
# 49     Javier Hernández     D                Cádiz       7           27
#
# --- REDCARDS ---
#             Name         Position        Team        redCards  Appearances
# 0            Chimy Ávila     F           Real Betis      3         23
# 1           Oihan Sancet     M        Athletic Club      2         30
# 2        Nacho Fernández     D          Real Madrid      2         26
# 3         Alberto Moreno     D           Villarreal      2         26
# 4        Largie Ramazani     F              Almería      2         29
# 5         Santi Comesaña     M           Villarreal      2         24
# 6            Iván Villar     G           Celta Vigo      2         10
# 7        Domingos Duarte     D               Getafe      2         15
# 8        Jude Bellingham     M          Real Madrid      1         26
# 9             Iago Aspas     F           Celta Vigo      1         32
# 10          Aleix García     M            Girona FC      1         34
# 11          Sergio Ramos     D              Sevilla      1         25
# 12              Raphinha     F            Barcelona      1         26
# 13       Alejandro Baena     M           Villarreal      1         32
# 14       Daniel Carvajal     D          Real Madrid      1         26
# 15         Álvaro Valles     G           Las Palmas      1         34
# 16        Antonio Raíllo     D             Mallorca      1         23
# 17        Jonathan Viera     M              Almería      1         19
# 18  Giorgi Mamardashvili     G             Valencia      1         34
# 19         Nico Williams     M        Athletic Club      1         29
# 20           Álex Remiro     G        Real Sociedad      1         33
# 21                  Suso     M              Sevilla      1         28
# 22          Renato Tapia     M           Celta Vigo      1         19
# 23          Willian José     F           Real Betis      1         31
# 24             Loïc Badé     D              Sevilla      1         25
# 25         Álvaro Morata     F      Atlético Madrid      1         30
# 26         Álvaro García     M       Rayo Vallecano      1         29
# 27           Abdul Mumin     D       Rayo Vallecano      1         18
# 28           Mika Mármol     D           Las Palmas      1         33
# 29        Óscar Valentín     M       Rayo Vallecano      1         32
# 30       Thierry Correia     D             Valencia      1         28
# 31         Léo Baptistão     F              Almería      1         29
# 32         Igor Zubeldia     D        Real Sociedad      1         30
# 33           Jesús Navas     D              Sevilla      1         27
# 34         Yeray Álvarez     D        Athletic Club      1         16
# 35      Gabriel Paulista     D      Atlético Madrid      1         22
# 36         Nahuel Molina     D      Atlético Madrid      1         30
# 37          Stefan Savić     D      Atlético Madrid      1         22
# 38         Aitor Paredes     D        Athletic Club      1         32
# 39        Robert Navarro     M                Cádiz      1         25
# 40         Juanmi Latasa     F               Getafe      1         30
# 41        Antonio Blanco     M     Deportivo Alavés      1         31
# 42          Víctor Chust     D                Cádiz      1         20
# 43            Jaime Mata     M               Getafe      1         32
# 44            Lucas Boyé     F              Granada      1         28
# 45      Alejandro Catena     D              Osasuna      1         27
# 46         Omar Alderete     D               Getafe      1         28
# 47        Edgar González     D              Almería      1         29
# 48         Jon Moncayola     M              Osasuna      1         30
# 49         Javier Guerra     M             Valencia      1         33
#
# --- SAVES ---
#             Name          Position        Team        saves  Appearances
# 0         Filip Jörgensen     G           Villarreal   137       34
# 1         Augusto Batalla     G              Granada    59       17
# 2             David Soria     G               Getafe   120       35
# 3          Luís Maximiano     G              Almería   109       32
# 4         Paulo Gazzaniga     G            Girona FC   115       35
# 5        Jeremías Ledesma     G                Cádiz   101       32
# 6          Vicente Guaita     G           Celta Vigo    81       26
# 7           Álvaro Valles     G           Las Palmas   104       34
# 8            Ørjan Nyland     G              Sevilla    64       21
# 9               Rui Silva     G           Real Betis    79       26
# 10     Stole Dimitrievski     G       Rayo Vallecano   104       35
# 11   Giorgi Mamardashvili     G             Valencia    99       34
# 12       Predrag Rajković     G             Mallorca    95       34
# 13         Sergio Herrera     G              Osasuna    85       31
# 14              Jan Oblak     G      Atlético Madrid    95       35
# 15             Unai Simón     G        Athletic Club    92       34
# 16         Antonio Sivera     G     Deportivo Alavés    87       34
# 17  Marc-André ter Stegen     G            Barcelona    60       24
# 18            Álex Remiro     G        Real Sociedad    80       33
# 19           Andriy Lunin     G          Real Madrid    45       20
#
# --- GOALSPREVENTED ---
#             Name          Position        Team        goalsPrevented  Appearances
# 0    Giorgi Mamardashvili     G             Valencia      8.73540         34
# 1              Unai Simón     G        Athletic Club      5.92050         34
# 2           Álvaro Valles     G           Las Palmas      5.44030         34
# 3             David Soria     G               Getafe      5.28360         35
# 4            Andriy Lunin     G          Real Madrid      5.17150         20
# 5         Paulo Gazzaniga     G            Girona FC      5.06191         35
# 6               Rui Silva     G           Real Betis      3.42750         26
# 7          Vicente Guaita     G           Celta Vigo      2.56030         26
# 8      Stole Dimitrievski     G       Rayo Vallecano      2.52540         35
# 9            Ørjan Nyland     G              Sevilla      2.44640         21
# 10         Antonio Sivera     G     Deportivo Alavés      1.62530         34
# 11      Kepa Arrizabalaga     G          Real Madrid      1.56590         13
# 12            Álex Remiro     G        Real Sociedad      0.91814         33
# 13          Dominik Greif     G             Mallorca      0.65950          1
# 14       Thibaut Courtois     G          Real Madrid      0.58560          2
# 15        Filip Jörgensen     G           Villarreal      0.53853         34
# 16          Claudio Bravo     G           Real Betis      0.47880          7
# 17              David Gil     G                Cádiz      0.12220          4
# 18           Diego Mariño     G              Almería      0.05100          1
# 19       Predrag Rajković     G             Mallorca      0.04092         34
# 20            Jesús Owono     G     Deportivo Alavés     -0.04470          1
# 21           Unai Marrero     G        Real Sociedad     -0.13950          2
# 22             Pepe Reina     G           Villarreal     -0.21760          1
# 23            Iván Villar     G           Celta Vigo     -0.32490         10
# 24      Francisco Vieites     G           Real Betis     -0.32690          3
# 25        Cristian Rivero     G             Valencia     -0.47720          1
# 26        Aarón Escandell     G           Las Palmas     -0.51590          2
# 27     Julen Agirrezabala     G        Athletic Club     -0.63070          1
# 28       Jeremías Ledesma     G                Cádiz     -0.72480         32
# 29         Sergio Herrera     G              Osasuna     -0.86730         31
# 30                   Bono     G              Sevilla     -0.88480          1
# 31         André Ferreira     G              Granada     -0.93270         15
# 32              Jan Oblak     G      Atlético Madrid     -1.27780         35
# 33         Jaume Doménech     G             Valencia     -1.31100          2
# 34  Marc-André ter Stegen     G            Barcelona     -1.40380         24
# 35        Aitor Fernández     G              Osasuna     -1.54030          5
# 36      Fernando Martínez     G              Almería     -2.09270          2
# 37        Marko Dmitrović     G              Sevilla     -2.41900         13
# 38         Luís Maximiano     G              Almería     -2.57600         32
# 39             Iñaki Peña     G            Barcelona     -3.10810         10
# 40         Raúl Fernández     G              Granada     -3.16610          4
# 41        Augusto Batalla     G              Granada     -5.05590         17
#
# --- MOSTCONCEDED ---
#             Name          Position        Team       mostConceded  Appearances
# 0          Luís Maximiano     G              Almería      N/A          32
# 1         Filip Jörgensen     G           Villarreal      N/A          34
# 2         Augusto Batalla     G              Granada      N/A          17
# 3          Sergio Herrera     G              Osasuna      N/A          31
# 4        Jeremías Ledesma     G                Cádiz      N/A          32
# 5          Vicente Guaita     G           Celta Vigo      N/A          26
# 6             David Soria     G               Getafe      N/A          35
# 7         Paulo Gazzaniga     G            Girona FC      N/A          35
# 8               Rui Silva     G           Real Betis      N/A          26
# 9      Stole Dimitrievski     G       Rayo Vallecano      N/A          35
# 10          Álvaro Valles     G           Las Palmas      N/A          34
# 11       Predrag Rajković     G             Mallorca      N/A          34
# 12         Antonio Sivera     G     Deportivo Alavés      N/A          34
# 13              Jan Oblak     G      Atlético Madrid      N/A          35
# 14  Marc-André ter Stegen     G            Barcelona      N/A          24
# 15           Ørjan Nyland     G              Sevilla      N/A          21
# 16   Giorgi Mamardashvili     G             Valencia      N/A          34
# 17             Unai Simón     G        Athletic Club      N/A          34
# 18            Álex Remiro     G        Real Sociedad      N/A          33
# 19           Andriy Lunin     G          Real Madrid      N/A          20
#
# --- LEASTCONCEDED ---
#             Name          Position        Team       leastConceded  Appearances
# 0            Andriy Lunin     G          Real Madrid       N/A          20
# 1             Álex Remiro     G        Real Sociedad       N/A          33
# 2              Unai Simón     G        Athletic Club       N/A          34
# 3    Giorgi Mamardashvili     G             Valencia       N/A          34
# 4            Ørjan Nyland     G              Sevilla       N/A          21
# 5   Marc-André ter Stegen     G            Barcelona       N/A          24
# 6               Jan Oblak     G      Atlético Madrid       N/A          35
# 7          Antonio Sivera     G     Deportivo Alavés       N/A          34
# 8        Predrag Rajković     G             Mallorca       N/A          34
# 9           Álvaro Valles     G           Las Palmas       N/A          34
# 10     Stole Dimitrievski     G       Rayo Vallecano       N/A          35
# 11              Rui Silva     G           Real Betis       N/A          26
# 12        Paulo Gazzaniga     G            Girona FC       N/A          35
# 13            David Soria     G               Getafe       N/A          35
# 14         Vicente Guaita     G           Celta Vigo       N/A          26
# 15       Jeremías Ledesma     G                Cádiz       N/A          32
# 16         Sergio Herrera     G              Osasuna       N/A          31
# 17        Augusto Batalla     G              Granada       N/A          17
# 18        Filip Jörgensen     G           Villarreal       N/A          34
# 19         Luís Maximiano     G              Almería       N/A          32
#
# --- CLEANSHEET ---
#             Name          Position        Team        cleanSheet  Appearances
# 0              Unai Simón     G        Athletic Club      16          34
# 1    Giorgi Mamardashvili     G             Valencia      13          34
# 2             Álex Remiro     G        Real Sociedad      13          33
# 3      Stole Dimitrievski     G       Rayo Vallecano      13          35
# 4   Marc-André ter Stegen     G            Barcelona      12          24
# 5         Paulo Gazzaniga     G            Girona FC      11          35
# 6               Jan Oblak     G      Atlético Madrid      11          35
# 7            Andriy Lunin     G          Real Madrid      10          20
# 8             David Soria     G               Getafe      10          35
# 9          Antonio Sivera     G     Deportivo Alavés      10          34
# 10              Rui Silva     G           Real Betis       9          26
# 11       Predrag Rajković     G             Mallorca       9          34
# 12         Sergio Herrera     G              Osasuna       9          31
# 13       Jeremías Ledesma     G                Cádiz       7          32
# 14          Álvaro Valles     G           Las Palmas       7          34
# 15      Kepa Arrizabalaga     G          Real Madrid       7          13
# 16         Vicente Guaita     G           Celta Vigo       6          26
# 17           Ørjan Nyland     G              Sevilla       6          21
# 18         Luís Maximiano     G              Almería       6          32
# 19        Filip Jörgensen     G           Villarreal       5          34
# 20        Augusto Batalla     G              Granada       3          17
# 21       Thibaut Courtois     G          Real Madrid       2           2
# 22          Claudio Bravo     G           Real Betis       2           7
# 23        Marko Dmitrović     G              Sevilla       2          13
# 24             Iñaki Peña     G            Barcelona       2          10
# 25          Dominik Greif     G             Mallorca       1           1
# 26              David Gil     G                Cádiz       1           4
# 27      Francisco Vieites     G           Real Betis       1           3

# %% [markdown]
# #### Mejores jugadores por partido

# %%
import requests
import pandas as pd

def fetch_and_process_data(url, category):
    response = requests.get(url)
    data = response.json()

    # Procesar la categoría específica de topPlayers
    if category in data['topPlayers']:
        players_data = data['topPlayers'][category]
        players_list = []
        for player in players_data:
            player_details = {
                'Name': player['player']['name'],
                'Position': player['player']['position'],
                'Team': player['event']['homeTeam']['name'] + " vs. " + player['event']['awayTeam']['name'],
                'Match Score': f"{player.get('event', {}).get('homeScore', {}).get('display', 'N/A')}-{player.get('event', {}).get('awayScore', {}).get('display', 'N/A')}",
                'Statistic Value': player['statistic']
            }
            players_list.append(player_details)

        df = pd.DataFrame(players_list)
        return df
    else:
        return pd.DataFrame()  # Devuelve un DataFrame vacío si la categoría no existe
    
    
url = "http://www.sofascore.com/api/v1/unique-tournament/8/season/52376/top-players-per-game/all/overall"

# Lista de categorías para procesar
categories = [
    'rating', 'goals', 'goalAssist', 'expectedAssists', 'expectedGoals',
    'errorLeadToAGoal', 'bigChanceMissed', 'bigChanceCreated', 'keyPass',
    'accuratePass', 'totalPass', 'wonContest', 'totalTackle', 'totalClearance',
    'saves', 'goalsPrevented', 'penaltySave', 'penaltyMiss'
]

# Procesar y mostrar cada categoría
for category in categories:
    print(f"--- {category.upper()} ---")
    df_category = fetch_and_process_data(url, category)
    if not df_category.empty:
        print(df_category)
    else:
        print("No data available for this category.")
    print("\n")
# Out:
# --- RATING ---
#           Name        Position              Team             Match Score  Statistic Value
# 0          Iago Aspas     F        Celta Vigo vs. Las Palmas      4-1          10.0
# 1  Luis Javier Suárez     F              Almería vs. Granada      3-3          10.0
# 2             Rodrygo     F         Real Madrid vs. Valencia      5-1          10.0
# 3      Luís Maximiano     G       Rayo Vallecano vs. Almería      0-1           9.8
# 4       Ferran Torres     F         Real Betis vs. Barcelona      2-4           9.8
# 5       Gerard Moreno     F     Villarreal vs. Athletic Club      2-3           9.8
# 6         Luka Modrić     M       Real Madrid vs. Celta Vigo      4-0           9.7
# 7               Portu     F          Girona FC vs. Barcelona      4-2           9.6
# 8     Filip Jörgensen     G            Getafe vs. Villarreal      0-0           9.6
# 9          Unai Simón     G         Getafe vs. Athletic Club      0-2           9.6
#
#
# --- GOALS ---
#           Name        Position               Team              Match Score  Statistic Value
# 0        Artem Dovbyk     F              Girona FC vs. Sevilla      5-1            3
# 1   Antoine Griezmann     F     Celta Vigo vs. Atlético Madrid      0-3            3
# 2  Luis Javier Suárez     F                Almería vs. Granada      3-3            3
# 3   José Luis Morales     F             Villarreal vs. Osasuna      3-1            3
# 4       Álvaro Morata     F      Girona FC vs. Atlético Madrid      4-3            3
# 5       Ferran Torres     F           Real Betis vs. Barcelona      2-4            3
# 6  Robert Lewandowski     F             Barcelona vs. Valencia      4-2            3
# 7   Alexander Sørloth     F             Villarreal vs. Granada      5-1            3
# 8         Abdón Prats     F             Girona FC vs. Mallorca      5-3            2
# 9    Cristhian Stuani     F             Girona FC vs. Valencia      2-1            2
#
#
# --- GOALASSIST ---
#          Name        Position                 Team                Match Score  Statistic Value
# 0    Largie Ramazani     F                    Almería vs. Granada      3-3            3
# 1    Alejandro Baena     M          Villarreal vs. Rayo Vallecano      3-0            3
# 2        Dani Parejo     M                 Villarreal vs. Granada      5-1            3
# 3  Federico Valverde     M                Osasuna vs. Real Madrid      2-4            3
# 4      Nico Williams     M              Osasuna vs. Athletic Club      0-2            2
# 5    Rodrigo de Paul     M     Rayo Vallecano vs. Atlético Madrid      0-7            2
# 6               Suso     M                    Granada vs. Sevilla      0-3            2
# 7              Sávio     M                  Girona FC vs. Sevilla      5-1            2
# 8        Fran García     D          Real Madrid vs. Real Sociedad      2-1            2
# 9   Miguel Gutiérrez     D                    Girona FC vs. Cádiz      4-1            2
#
#
# --- EXPECTEDASSISTS ---
#           Name        Position               Team              Match Score  Statistic Value
# 0               Sávio     M             Girona FC vs. Mallorca      5-3        1.321020
# 1     Marcos Llorente     M     Atlético Madrid vs. Villarreal      3-1        1.226240
# 2               Sávio     M              Girona FC vs. Sevilla      5-1        1.178190
# 3    Viktor Tsygankov     M       Rayo Vallecano vs. Girona FC      1-2        1.026130
# 4  Robert Lewandowski     F      Atlético Madrid vs. Barcelona      0-3        0.941563
# 5          Iago Aspas     F            Celta Vigo vs. Mallorca      0-1        0.936738
# 6      Manuel Sánchez     D               Celta Vigo vs. Cádiz      1-1        0.933323
# 7          Iago Aspas     F             Celta Vigo vs. Granada      1-0        0.932119
# 8          Iago Aspas     F          Celta Vigo vs. Villarreal      3-2        0.922667
# 9      İlkay Gündoğan     M                Barcelona vs. Cádiz      2-0        0.922295
#
#
# --- EXPECTEDGOALS ---
#            Name         Position               Team              Match Score  Statistic Value
# 0    Luis Javier Suárez     F                Almería vs. Granada      3-3         2.3071
# 1          Artem Dovbyk     F       Rayo Vallecano vs. Girona FC      1-2         1.9799
# 2          Ángel Correa     F     Atlético Madrid vs. Las Palmas      5-0         1.9637
# 3     José Luis Morales     F             Villarreal vs. Osasuna      3-1         1.9198
# 4  Jørgen Strand Larsen     F          Celta Vigo vs. Villarreal      3-2         1.9132
# 5       Vinícius Júnior     F          Real Madrid vs. Barcelona      3-2         1.8650
# 6       Vinícius Júnior     F           Valencia vs. Real Madrid      2-2         1.7443
# 7          Artem Dovbyk     F           Las Palmas vs. Girona FC      0-2         1.7424
# 8          Artem Dovbyk     F      Atlético Madrid vs. Girona FC      3-1         1.7319
# 9                Pepelu     M            Valencia vs. Villarreal      3-1         1.6763
#
#
# --- ERRORLEADTOAGOAL ---
#          Name        Position                Team               Match Score  Statistic Value
# 0        David López     D             Girona FC vs. Real Betis      3-2            2
# 1              Chumi     D               Real Betis vs. Almería      3-2            2
# 2        Fran García     D               Real Madrid vs. Getafe      2-1            1
# 3  Gonzalo Escalante     M                  Girona FC vs. Cádiz      4-1            1
# 4          Dion Lopy     M                   Almería vs. Getafe      1-3            1
# 5  Houboulang Mendes     D               Almería vs. Las Palmas      1-2            1
# 6      Nahuel Molina     D        Barcelona vs. Atlético Madrid      1-0            1
# 7       João Cancelo     D             Barcelona vs. Villarreal      3-5            1
# 8     Óscar Valentín     M     Athletic Club vs. Rayo Vallecano      4-0            1
# 9         Jhon Solís     M        Atlético Madrid vs. Girona FC      3-1            1
#
#
# --- BIGCHANCEMISSED ---
#         Name       Position               Team               Match Score  Statistic Value
# 0       Cyle Larin     F             Mallorca vs. Celta Vigo      1-1            4
# 1  Vinícius Júnior     F              Getafe vs. Real Madrid      0-2            3
# 2     Isaac Romero     F              Las Palmas vs. Sevilla      0-2            3
# 3      Kike García     F     Deportivo Alavés vs. Celta Vigo      3-0            3
# 4    Álvaro Morata     F        Atlético Madrid vs. Mallorca      1-0            3
# 5     Isaac Romero     F           Sevilla vs. Real Sociedad      3-2            3
# 6    Álvaro Morata     F       Girona FC vs. Atlético Madrid      4-3            3
# 7     Isaac Romero     F                 Almería vs. Sevilla      2-2            3
# 8   Iñaki Williams     M         Athletic Club vs. Girona FC      3-2            3
# 9    Luiz Henrique     M            Real Betis vs. Barcelona      2-4            3
#
#
# --- BIGCHANCECREATED ---
#          Name       Position               Team              Match Score  Statistic Value
# 0        Iago Aspas     F            Celta Vigo vs. Mallorca      0-1            4
# 1   Marcos Llorente     M     Atlético Madrid vs. Villarreal      3-1            3
# 2   Largie Ramazani     F                Almería vs. Granada      3-3            3
# 3  Miguel Gutiérrez     D                Girona FC vs. Cádiz      4-1            3
# 4  Viktor Tsygankov     M       Rayo Vallecano vs. Girona FC      1-2            3
# 5    Sergio Arribas     M       Almería vs. Deportivo Alavés      0-3            3
# 6   Rodrigo de Paul     M      Girona FC vs. Atlético Madrid      4-3            3
# 7       Roger Martí     F                  Cádiz vs. Sevilla      2-2            3
# 8     Gerard Moreno     F       Villarreal vs. Athletic Club      2-3            3
# 9    Bryan Zaragoza     M                  Granada vs. Cádiz      2-0            3
#
#
# --- KEYPASS ---
#         Name       Position              Team             Match Score  Statistic Value
# 0   İlkay Gündoğan     M         Barcelona vs. Villarreal      3-5           10
# 1      Luka Modrić     M       Real Madrid vs. Celta Vigo      4-0            8
# 2  Alejandro Baena     M             Villarreal vs. Cádiz      0-0            8
# 3       Toni Kroos     M           Real Madrid vs. Getafe      2-1            7
# 4         Raphinha     F            Barcelona vs. Almería      3-2            7
# 5      Luka Modrić     M         Real Madrid vs. Mallorca      1-0            7
# 6   Carlos Vicente     M     Sevilla vs. Deportivo Alavés      2-3            7
# 7       Iago Aspas     F        Celta Vigo vs. Villarreal      3-2            7
# 8   İlkay Gündoğan     M            Barcelona vs. Almería      3-2            7
# 9   Jonathan Viera     M           Almería vs. Villarreal      1-2            6
#
#
# --- ACCURATEPASS ---
#          Name       Position                  Team                 Match Score  Statistic Value
# 0              Koke     M           Celta Vigo vs. Atlético Madrid      0-3           151
# 1      Jules Koundé     D                 Barcelona vs. Celta Vigo      3-2           135
# 2              Koke     M     Atlético Madrid vs. Deportivo Alavés      2-1           127
# 3       Luka Modrić     M                    Real Madrid vs. Cádiz      3-0           123
# 4        Toni Kroos     M                  Real Madrid vs. Granada      2-0           122
# 5       Axel Witsel     D                Atlético Madrid vs. Cádiz      3-2           122
# 6      Jules Koundé     D                     Getafe vs. Barcelona      0-0           121
# 7   Frenkie de Jong     M                     Getafe vs. Barcelona      0-0           120
# 8  Kirian Rodríguez     M                Celta Vigo vs. Las Palmas      4-1           118
# 9       Mika Mármol     D                   Granada vs. Las Palmas      1-1           117
#
#
# --- TOTALPASS ---
#          Name       Position                  Team                 Match Score  Statistic Value
# 0              Koke     M           Celta Vigo vs. Atlético Madrid      0-3           157
# 1      Jules Koundé     D                 Barcelona vs. Celta Vigo      3-2           141
# 2              Koke     M     Atlético Madrid vs. Deportivo Alavés      2-1           137
# 3      Jules Koundé     D                     Getafe vs. Barcelona      0-0           132
# 4   Frenkie de Jong     M                     Getafe vs. Barcelona      0-0           131
# 5        Toni Kroos     M                  Real Madrid vs. Granada      2-0           130
# 6       Axel Witsel     D                Atlético Madrid vs. Cádiz      3-2           130
# 7  Kirian Rodríguez     M                Celta Vigo vs. Las Palmas      4-1           129
# 8       Eric García     D              Athletic Club vs. Girona FC      3-2           128
# 9       Luka Modrić     M                    Real Madrid vs. Cádiz      3-0           127
#
#
# --- WONCONTEST ---
#         Name       Position               Team              Match Score  Statistic Value
# 0          Rodrygo     F         Real Betis vs. Real Madrid      1-1           10
# 1  Vinícius Júnior     F     Real Madrid vs. Rayo Vallecano      0-0           10
# 2  Alberto Moleiro     M          Real Betis vs. Las Palmas      1-0            9
# 3             Isco     M          Celta Vigo vs. Real Betis      2-1            8
# 4    Luiz Henrique     M             Real Betis vs. Granada      1-0            8
# 5  Largie Ramazani     F             Almería vs. Celta Vigo      2-3            8
# 6          Rodrygo     F         Celta Vigo vs. Real Madrid      0-1            8
# 7       João Félix     F     Barcelona vs. Deportivo Alavés      2-1            7
# 8  Vinícius Júnior     F           Real Madrid vs. Valencia      5-1            7
# 9            Sávio     M      Atlético Madrid vs. Girona FC      3-1            7
#
#
# --- TOTALTACKLE ---
#          Name        Position               Team              Match Score  Statistic Value
# 0  Eduardo Camavinga     M     Rayo Vallecano vs. Real Madrid      1-1           10
# 1    Óscar de Marcos     D         Athletic Club vs. Valencia      2-2           10
# 2     Óscar Valentín     M     Real Madrid vs. Rayo Vallecano      0-0           10
# 3     Juanlu Sánchez     D                Osasuna vs. Sevilla      0-0           10
# 4       Aitor Ruibal     D           Real Betis vs. Girona FC      1-1            9
# 5  Eduardo Camavinga     M          Girona FC vs. Real Madrid      0-3            9
# 6    Guido Rodríguez     M             Real Betis vs. Almería      3-2            9
# 7        Lucas Pires     D                  Cádiz vs. Sevilla      2-2            9
# 8       Franco Cervi     M          Villarreal vs. Celta Vigo      3-2            8
# 9               Koke     M       Atlético Madrid vs. Valencia      2-0            8
#
#
# --- TOTALCLEARANCE ---
#             Name          Position               Team              Match Score  Statistic Value
# 0          Martin Valjent     D         Mallorca vs. Athletic Club      0-0           14
# 1             Mika Mármol     D      Rayo Vallecano vs. Las Palmas      0-2           13
# 2              Unai Núñez     D             Osasuna vs. Celta Vigo      0-3           13
# 3            Sergio Ramos     D             Villarreal vs. Sevilla      3-2           13
# 4             Daley Blind     D      Girona FC vs. Atlético Madrid      4-3           12
# 5  Aleksandar Radovanović     D          Almería vs. Athletic Club      0-0           12
# 6             Abdul Mumin     D     Real Madrid vs. Rayo Vallecano      0-0           12
# 7        Abdelkabir Abqar     D      Mallorca vs. Deportivo Alavés      0-0           12
# 8              Rafa Marín     D       Almería vs. Deportivo Alavés      0-3           12
# 9        Alejandro Catena     D                 Osasuna vs. Getafe      3-2           12
#
#
# --- SAVES ---
#         Name       Position                 Team                 Match Score  Statistic Value
# 0        Rui Silva     G          Atlético Madrid vs. Real Betis      2-1           11
# 1   Vicente Guaita     G              Real Madrid vs. Celta Vigo      4-0           11
# 2   Luís Maximiano     G              Rayo Vallecano vs. Almería      0-1           10
# 3      David Soria     G                      Almería vs. Getafe      1-3           10
# 4      David Soria     G                  Real Madrid vs. Getafe      2-1           10
# 5  Filip Jörgensen     G                   Getafe vs. Villarreal      0-0            9
# 6       Unai Simón     G                Getafe vs. Athletic Club      0-2            9
# 7   Antonio Sivera     G     Rayo Vallecano vs. Deportivo Alavés      2-0            9
# 8  Paulo Gazzaniga     G           Girona FC vs. Atlético Madrid      4-3            9
# 9      David Soria     G                   Celta Vigo vs. Getafe      2-2            9
#
#
# --- GOALSPREVENTED ---
#            Name          Position              Team              Match Score  Statistic Value
# 0          Álvaro Valles     G      Athletic Club vs. Las Palmas      1-0         3.7537
# 1             Unai Simón     G          Getafe vs. Athletic Club      0-2         3.2442
# 2            David Soria     G             Celta Vigo vs. Getafe      2-2         2.7460
# 3              Rui Silva     G            Almería vs. Real Betis      0-0         2.3813
# 4  Marc-André ter Stegen     G       Real Sociedad vs. Barcelona      0-1         2.1650
# 5     Stole Dimitrievski     G     Las Palmas vs. Rayo Vallecano      0-1         2.1286
# 6       Predrag Rajković     G        Real Sociedad vs. Mallorca      1-0         2.0596
# 7       Predrag Rajković     G              Mallorca vs. Sevilla      1-0         1.9904
# 8         Antonio Sivera     G      Almería vs. Deportivo Alavés      0-3         1.8073
# 9          Álvaro Valles     G            Sevilla vs. Las Palmas      1-0         1.7551
#
#
# --- PENALTYSAVE ---
#            Name         Position                 Team                Match Score  Statistic Value
# 0            Unai Simón     G               Getafe vs. Athletic Club      0-2            1
# 1         Álvaro Valles     G           Athletic Club vs. Las Palmas      1-0            1
# 2             Rui Silva     G         Atlético Madrid vs. Real Betis      2-1            1
# 3       Paulo Gazzaniga     G               Las Palmas vs. Girona FC      0-2            1
# 4    Stole Dimitrievski     G          Las Palmas vs. Rayo Vallecano      0-1            1
# 5  Giorgi Mamardashvili     G                Villarreal vs. Valencia      1-0            1
# 6      Predrag Rajković     G                 Barcelona vs. Mallorca      1-0            1
# 7            Unai Simón     G     Athletic Club vs. Deportivo Alavés      2-0            1
# 8        Sergio Herrera     G                Real Madrid vs. Osasuna      4-0            1
# 9  Giorgi Mamardashvili     G                   Osasuna vs. Valencia      0-1            1
#
#
# --- PENALTYMISS ---
#          Name       Position                 Team                Match Score  Statistic Value
# 0            Joselu     F              Real Madrid vs. Girona FC      4-0            1
# 1     Gerard Moreno     F           Athletic Club vs. Villarreal      1-1            1
# 2    Gorka Guruzeta     F           Athletic Club vs. Las Palmas      1-0            1
# 3        Luis Rioja     M     Athletic Club vs. Deportivo Alavés      2-0            1
# 4    Sandro Ramírez     F               Las Palmas vs. Girona FC      0-2            1
# 5        Ianis Hagi     M           Deportivo Alavés vs. Almería      1-0            1
# 6      Artem Dovbyk     F               Las Palmas vs. Girona FC      0-2            1
# 7   Antonio Puertas     M                    Almería vs. Granada      3-3            1
# 8  Munir El Haddadi     F          Las Palmas vs. Rayo Vallecano      0-1            1
# 9       Kike García     F          Deportivo Alavés vs. Valencia      1-0            1

# %% [markdown]
# #### Datos de un jugador

# %%
import requests
import pandas as pd

def fetch_player_seasons(url):
    response = requests.get(url)
    data = response.json()
    
    # Preparar una lista para recopilar la información procesada
    seasons_list = []
    for tournament_season in data['uniqueTournamentSeasons']:
        tournament_info = tournament_season['uniqueTournament']
        tournament_name = tournament_info['name']
        for season in tournament_season['seasons']:
            season_details = {
                'Tournament': tournament_name,
                'Season Name': season['name'],
                'Year': season['year'],
                'Season ID': season['id']
            }
            seasons_list.append(season_details)

    # Convertir la lista en un DataFrame para facilitar la visualización
    df = pd.DataFrame(seasons_list)
    return df

# URL de la API para obtener estadísticas de temporada de un jugador específico
url = "http://www.sofascore.com/api/v1/player/991011/statistics/seasons"

# Obtener y mostrar los datos procesados
player_seasons_df = fetch_player_seasons(url)
print(player_seasons_df)
# Out:
#                  Tournament                             Season Name                    Year     Season ID
# 0                                 LaLiga                               LaLiga 23/24      23/24    52376
# 1                    Supercopa de España                   Supercopa de España 2024       2024    56121
# 2   European Championship, Qualification  European Championship 2024, Qualification       2024    46599
# 3                  UEFA Champions League                UEFA Champions League 23/24      23/24    52162
# 4                  UEFA Champions League                UEFA Champions League 22/23      22/23    41897
# 5                  UEFA Champions League                UEFA Champions League 21/22      21/22    36886
# 6                  UEFA Champions League                UEFA Champions League 20/21      20/21    29267
# 7                             Bundesliga                           Bundesliga 22/23      22/23    42268
# 8                             Bundesliga                           Bundesliga 21/22      21/22    37166
# 9                             Bundesliga                           Bundesliga 20/21      20/21    28210
# 10                             DFB Pokal                            DFB Pokal 22/23      22/23    41962
# 11                             DFB Pokal                            DFB Pokal 21/22      21/22    37289
# 12                             DFB Pokal                            DFB Pokal 20/21      20/21    29194
# 13                    World Championship                             World Cup 2022       2022    41087
# 14                   UEFA Nations League                  UEFA Nations League 22/23  2022-2024    40128
# 15         World Championship Qual. UEFA                WC Qualification, UEFA 2022       2022    35021
# 16                    UEFA Europa League                   UEFA Europa League 21/22      21/22    37725
# 17                             Super Cup                             Super Cup 2021       2021    36760
# 18                             Super Cup                             Super Cup 2020       2020    29295
# 19                 European Championship                              Euro Cup 2020       2021    26542
# 20                                FA Cup                               FA Cup 19/20      19/20    25944
# 21                               EFL Cup                              EFL Cup 19/20      19/20    24004
# 22                          Championship                         Championship 19/20      19/20    23976

# %%
import requests
import pandas as pd

def fetch_player_statistics(url):
    response = requests.get(url)
    data = response.json()

    # Extraer las estadísticas del jugador
    stats = data['statistics']
    
    # Crear un diccionario para recopilar la información procesada
    player_stats = {
        'Team': data['team']['name'],
        'Rating': stats['rating'],
        'Total Rating': stats['totalRating'],
        'Goals': stats['goals'],
        'Assists': stats['assists'],
        'Expected Goals': stats['expectedGoals'],
        'Expected Assists': stats['expectedAssists'],
        'Accurate Passes': stats['accuratePasses'],
        'Inaccurate Passes': stats['inaccuratePasses'],
        'Total Passes': stats['totalPasses'],
        'Successful Dribbles': stats['successfulDribbles'],
        'Yellow Cards': stats['yellowCards'],
        'Red Cards': stats['redCards'],
        'Shots On Target': stats['shotsOnTarget'],
        'Total Shots': stats['totalShots'],
        'Minutes Played': stats['minutesPlayed'],
        'Appearances': stats['appearances']
    }

    # Crear DataFrame para una visualización más clara
    df = pd.DataFrame([player_stats])
    return df

# URL de la API para obtener estadísticas detalladas de un jugador en una temporada y torneo específicos
url = "http://www.sofascore.com/api/v1/player/991011/unique-tournament/8/season/52376/statistics/overall"

# Obtener y mostrar los datos procesados
player_stats_df = fetch_player_statistics(url)
print(player_stats_df)
# Out:
#       Team      Rating  Total Rating  Goals  Assists  Expected Goals  Expected Assists  Accurate Passes  Inaccurate Passes  Total Passes  Successful Dribbles  Yellow Cards  Red Cards  Shots On Target  Total Shots  Minutes Played  Appearances
# 0  Real Madrid     8         208       18       4         10.8044         3.641917           1194               142             1336              44                 5           1            32             58            2144           26

# %%
import requests
import pandas as pd

def fetch_last_ratings(url):
    response = requests.get(url)
    data = response.json()

    # Preparar una lista para recopilar la información procesada
    ratings_list = []
    for rating_entry in data['lastRatings']:
        event_info = rating_entry['event']
        home_team = event_info['homeTeam']['name']
        away_team = event_info['awayTeam']['name']
        home_score = event_info['homeScore']['display']
        away_score = event_info['awayScore']['display']
        
        # Crear un diccionario para cada entrada
        rating_details = {
            'Event ID': rating_entry['eventId'],
            'Tournament': event_info['tournament']['name'],
            'Home Team': home_team,
            'Away Team': away_team,
            'Home Score': home_score,
            'Away Score': away_score,
            'Match Date': pd.to_datetime(rating_entry['startTimestamp'], unit='s'),
            'Player Rating': rating_entry['rating'],
            'Is Home': rating_entry['isHome'],
            'Opponent': rating_entry['opponent']['name']
        }
        ratings_list.append(rating_details)

    # Convertir la lista en un DataFrame para facilitar la visualización
    df = pd.DataFrame(ratings_list)
    return df

# URL de la API para obtener las últimas calificaciones de un jugador en una temporada y torneo específicos
url = "http://www.sofascore.com/api/v1/player/103417/unique-tournament/8/season/52376/last-ratings"

# Obtener y mostrar los datos procesados
player_ratings_df = fetch_last_ratings(url)
print(player_ratings_df)
# Out:
#    Event ID Tournament  Home Team   Away Team   Home Score  Away Score      Match Date      Player Rating  Is Home   Opponent
# 0  11368629   LaLiga    Real Betis     Almería       3           2     2024-05-12 19:00:00       8.8         True      Almería
# 1  11368677   LaLiga    Real Betis     Sevilla       1           1     2024-04-28 19:00:00       7.7         True      Sevilla
# 2  11368671   LaLiga      Valencia  Real Betis       1           2     2024-04-20 16:30:00       7.3        False     Valencia
# 3  11368709   LaLiga    Real Betis  Celta Vigo       2           1     2024-04-12 19:00:00       7.7         True   Celta Vigo
# 4  11368693   LaLiga     Girona FC  Real Betis       3           2     2024-03-31 14:15:00       7.0        False    Girona FC

# %% [markdown]
# #### Datos de equipo

# %%
import pandas as pd
import requests

# Suponiendo que el archivo 'teams.csv' esté en el mismo directorio que el script o ajustar la ruta según corresponda
df_teams = pd.read_csv('teams.csv')

results = pd.DataFrame()

def fetch_team_statistics(team_id, team_name):
    url = f"https://www.sofascore.com/api/v1/team/{team_id}/unique-tournament/8/season/52376/statistics/overall"
    response = requests.get(url)
    data = response.json()
    if 'statistics' in data:
        stats = data['statistics']
        stats['Team Name'] = team_name  # Añade el nombre del equipo al diccionario
        return stats
    else:
        return None

# Procesando cada equipo y almacenando los resultados
for index, row in df_teams.iterrows():
    team_id = row['id']
    team_name = row['name']  # Asegúrate de que la columna se llama 'name' en tu DataFrame
    team_stats = fetch_team_statistics(team_id, team_name)
    if team_stats:
        # Convertir el diccionario de estadísticas en un DataFrame
        stats_df = pd.DataFrame([team_stats])
        stats_df['Team ID'] = team_id  # Añade el ID del equipo para referencia
        # Reordenar las columnas para que 'Team Name' y 'Team ID' sean las primeras
        columns_order = ['Team Name', 'Team ID'] + [col for col in stats_df.columns if col not in ['Team Name', 'Team ID']]
        stats_df = stats_df[columns_order]
        # Concatenar con el DataFrame de resultados
        results = pd.concat([results, stats_df], ignore_index=True)

# Opcional: Guardar los resultados en un archivo CSV
results.to_csv('team_statistics.csv', index=False)
print(results)
# Out:
#        Team Name      Team ID  goalsScored  goalsConceded  ownGoals  assists  shots  penaltyGoals  penaltiesTaken  freeKickGoals  freeKickShots  goalsFromInsideTheBox  goalsFromOutsideTheBox  shotsFromInsideTheBox  shotsFromOutsideTheBox  headedGoals  leftFootGoals  rightFootGoals  bigChances  bigChancesCreated  bigChancesMissed  shotsOnTarget  shotsOffTarget  blockedScoringAttempt  successfulDribbles  dribbleAttempts  corners  hitWoodwork  fastBreaks  fastBreakGoals  fastBreakShots  averageBallPossession  totalPasses  accuratePasses  accuratePassesPercentage  totalOwnHalfPasses  accurateOwnHalfPasses  accurateOwnHalfPassesPercentage  totalOppositionHalfPasses  accurateOppositionHalfPasses  accurateOppositionHalfPassesPercentage  totalLongBalls  accurateLongBalls  accurateLongBallsPercentage  totalCrosses  accurateCrosses  accurateCrossesPercentage  cleanSheets  tackles  interceptions  saves  errorsLeadingToGoal  errorsLeadingToShot  penaltiesCommited  penaltyGoalsConceded  \
# 0          Barcelona    2817       88             50           0        28     998         4              4              0             10                 114                     10                     672                      46               12            10              32              0            170                 90             154             282                244                   108               898          260        10            6             0              30              86.458542            3494          10692             112.350420                11736                 5394                    168.330953                        3332                         6346                            20.598726                     1580             1222                  74.481129                820             62                35.500049               4         344         322         14            8                    6                   0                    2
# 1        Real Madrid    2829       28             22           0       104     824         2              4              0              2                  16                      8                     394                     166               16             2              28            158             52                 84              30             170                 16                   734                50          342        20           64             8              36              31.571752           18370          36214             178.969696                16248                17784                     43.146043                       13762                         9636                           161.562984                      540              538                  84.136022                432             40                20.428563              26         540         122         66            0                    4                   0                    0
# 2   Deportivo Alavés    2885       42             36           0        20     364         4              2              0             14                  28                      0                     528                     224                0             2               8             98             44                 64              30             136                  4                   530               678          146        20           18             2              20               9.950598           19940          11964             123.517314                 1256                  156                     87.788983                        1838                         7770                            83.066837                       64              944                  68.250660               1084            196                37.298497               6         140          70        124            0                    6                   6                    4
# 3         Las Palmas    6577       46             24           2         2     632         0              4              0             26                   2                      4                     180                     206                0             6              16             74             34                 36             108             272                148                   280               398            4        12            2             0              14              39.341401           27270          25988             114.885849                 2312                14972                     45.876625                        5388                         7986                            55.566268                     2000              822                  28.449584                726             24                19.386345               8         612         246        112            4                    0                   2                    8
# 4            Granada   33779       40            114           2        20     464         0              8              0              6                  14                      0                     396                     226                6            12               4              2             26                 26             236             156                152                   416               972           84         0           28             2              26              35.200178           21604           3098             130.117921                 2902                  954                     46.982223                        7718                         2890                            62.442426                     2304               90                  38.346905                570            170                29.861658               2         420         410         94           14                   14                   0                    0
# 5          Girona FC   24264       50             40           0        66     370         6              0              0              6                  98                      6                      36                     134                6            14              32            164            126                110             220              74                116                   528              1076          132        18           12             0              30              24.993123           16010          26052             158.681209                  968                14742                    182.913782                         366                        14068                            59.624504                      198             1104                  63.023098                 84            158                42.065556              16          60         100        212            0                   10                   2                    0
# 6    Atlético Madrid    2836       72             34           0         2     706         2              4              0             10                  12                      8                     348                     170               24            12              54            118              2                104             122              24                 46                   228               392          236        12           28             6              10              25.809570            6428           3468             104.207269                12566                   84                    123.498355                       12058                         9124                            33.727379                     2302             1334                  86.407329                686            178                17.759055              14         642         108         56            4                    6                   2                    0
# 7      Athletic Club    2825       40             20           6         2     104         0              2              0              8                  86                      2                     644                     104                2            20              44            140             52                 10             296              18                184                    24               632          232         8           22             4              24              73.746802           26546          18002              89.143583                 2994                 5648                    173.997691                        6718                         4486                            27.680217                      954              138                  95.430857               1042            302                12.002254              28         398          64        100            0                    2                   0                    0
# 8      Real Sociedad    2824        6             68           0         0      36         4              0              0             10                  18                      0                     294                     300               14            12              12             84             40                 16             262               8                198                   232               106           42         8           14             6               8              81.316217            9160           7710              99.783702                 3962                  350                    145.322889                        9476                         6926                            25.184539                     1716              406                  91.153201                804             14                20.323455              16         836         130          0            4                   22                   2                    2
# 9         Real Betis    2816       60             58           2        50     910         2              2              0              8                  46                      6                      86                     286                0            14              42             72             66                 12             276             296                238                   444               614          366        10            6             4              20               6.838704           11818           6322              20.949879                14680                 5694                     69.298180                        7558                         3366                            70.296425                     1482              738                   9.947759                136            136                24.235001               2         710          22          0            0                   10                   4                    4
# 10        Villarreal    2819       44             14           0        66     332         6              4              0             14                  80                      0                      76                     206               12            30              32             92            106                 64              74             192                204                   438               970           98         8           44             8              14              61.538275           23588              4              66.214295                 9352                 8384                    103.904121                       16200                         1204                           138.914210                     2322              950                  66.769859                394            270                41.294203               6         336         262        196            0                   14                   4                    6
# 11          Valencia    2828        8             54           0        34     634         2             12              0             20                  40                      0                      94                     118                2            10              10             30             58                  2             106             196                 72                   474               232           52         4            4             0              10              21.033221           16650           3352              18.028010                12116                  226                     10.320425                       14272                         5616                            79.646910                       22              440                  11.377910               1048            202                42.000000               0         480         366         86            0                    0                   2                    0
# 12            Getafe    2859       16             58           0        20     518         8              0              0             18                  58                      0                      26                     288               28             4              16             70             12                 70             122              26                122                    80                78          264        12           22             0               4              29.556944           12072           1700             104.321926                 5348                 5880                    107.812631                       13330                         8116                            95.462671                     2796             1000                  75.031302                166            150                 9.152416               6         428         326        176            2                    0                   2                    0
# 13           Sevilla    2833        2             38           0        38     532         0              0              0             20                  72                      6                     316                       2               10            10               2             74             66                100             114             292                156                   404               524           36         4           26             0              26              62.462627            1866            740              62.503696                10540                12808                    104.817696                       16750                         4762                            78.610358                      220              724                  90.500742               1460            254                28.383284              14         296          18         10            0                   14                   4                    2
# 14           Osasuna    2820       74             56           0         2     728         0              4              0             22                  10                      0                     112                     146                8             8              10             32             42                 84              38             212                136                   228               288          288        16           18             0               2               7.857510           12184          17056              22.991627                 5656                 5990                     22.591773                        2692                        11810                            76.645373                     1202              652                  62.506054                734             78                 8.125188              14         894         170         96            4                   18                   0                    0
# 15          Mallorca    2826        4              6           0        12     708         0              0              0              2                  38                      0                     164                     152               14             2              16              2             24                 28             194              30                 36                   316               534          128         8           10             0               8               8.987729           21918          18540              26.421405                 8154                 8772                     18.205844                        8114                         4910                            17.374378                      466              818                  42.069557                568            186                43.562957               4         816         164        180            0                    6                   0                    0
# 16        Celta Vigo    2821       60             20           0         0     376         0              2              0             16                  16                      4                     224                      46               10            22              24            144             36                 32             164             190                 56                   286              1052          142         8           48            10              52              26.234226           12764            750             130.096710                12612                 9722                    121.258203                        4598                         5854                            45.675194                        2               32                  55.296622                314             34                 2.878253               2         834          48        182            2                    4                   4                    4
# 17    Rayo Vallecano    2818       34             70           0        12     424         0              2              0             68                  30                      4                      42                       0                0            14               6             74              4                 28             240             304                180                   240               454           50         2           22             0               0              86.000000            2752          14764             100.155676                 2958                 8260                    159.936764                       16762                         5052                           112.447979                      270             1020                  81.779370                696             80                41.764488              14        1070         418         32            8                    6                   2                    0
# 18             Cádiz    4488       14             60           0         2     366         2              0              0             36                   8                      0                     228                     196                2             2              12              4             60                 46             100              12                100                   350               338            8         4           12             0              10               4.177884           19070          14606              46.931953                 9532                 3778                     32.488935                       14652                         4132                           109.389300                      100              136                  60.363433                448            106                 1.677754               2         132         170         24            6                    0                   2                    0
# 19           Almería    2858       60            128           0        14     450         0              0              0              2                  10                      0                     462                     282                0            20               2             36             18                 48             184             174                 64                    66               884           34         6           56             2              18              23.014529           17802           7970              91.860612                11130                 1930                    139.796619                        1682                         2206                           100.061866                     1604              298                  56.087698                238            100                28.664513               4         284         368         38            2                    0                   2                   10
#
#     clearances  clearancesOffLine  lastManTackles  totalDuels  duelsWon  duelsWonPercentage  totalGroundDuels  groundDuelsWon  groundDuelsWonPercentage  totalAerialDuels  aerialDuelsWon  aerialDuelsWonPercentage  possessionLost  offsides  fouls  yellowCards  yellowRedCards  redCards  avgRating  accurateFinalThirdPassesAgainst  accurateOppositionHalfPassesAgainst  accurateOwnHalfPassesAgainst  accuratePassesAgainst  bigChancesAgainst  bigChancesCreatedAgainst  bigChancesMissedAgainst  clearancesAgainst  cornersAgainst  crossesSuccessfulAgainst  crossesTotalAgainst  dribbleAttemptsTotalAgainst  dribbleAttemptsWonAgainst  errorsLeadingToGoalAgainst  errorsLeadingToShotAgainst  hitWoodworkAgainst  interceptionsAgainst  keyPassesAgainst  longBallsSuccessfulAgainst  longBallsTotalAgainst  offsidesAgainst  redCardsAgainst  shotsAgainst  shotsBlockedAgainst  shotsFromInsideTheBoxAgainst  shotsFromOutsideTheBoxAgainst  shotsOffTargetAgainst  shotsOnTargetAgainst  blockedScoringAttemptAgainst  \
# 0       516             4                 0           3240        542         45.770381            1380              734                4.142101                952              244               23.222850              3160            8     564       108             0            2      4.721791                606                                6658                              1328                      8160                 108                     78                      60                     48               234                  220                    156                      694                          56                          4                           0                       2                   324                 318                    306                       44                  42               0              622              108                       280                            62                        250                    118                       132
# 1       594             0                 0            742       3194         29.641982            2244              500               48.979369                240              616               93.101825              6396          142     168        24             0            2      1.705297               2300                                5690                              8852                     21154                  70                     26                      42                   1102                74                  184                    686                      628                          22                          6                           6                       4                   422                 518                    228                      916                  46               0              658               26                        32                           200                        238                     48                        40
# 2        64             6                10            448        728         80.622392            2242             2152                8.634055               1192              786               33.244510              6632           64     486        82             0            0      8.342514                458                                 174                             13602                      5422                  24                     62                      80                    938               212                   64                    666                      790                         430                          0                          22                       4                   306                 124                    324                      460                  34               0              500              150                       364                           258                        142                    112                        54
# 3        20             0                12            652       3094         21.716925            2208             1876               14.853096                 74              328               89.275636              1722           76     560       130             0            0      9.459626                626                                1546                              1358                      3834                  16                    152                      86                     32               342                  266                   1170                      614                         114                          4                           2                      10                   524                 260                   1310                     1264                  70               6              338              104                       332                            56                         16                    216                       172
# 4       906             0                 0            214        866         17.739277            4880             2542               31.474830                778              336               13.385311              7238           68     736       162             0            0     12.470868               6296                                7480                              9268                     26714                 192                     82                      50                   1210               170                  230                   1306                      942                         482                          0                           0                       0                    62                 158                     84                     2926                 102               0              632               76                        14                           242                        132                     74                        88
# 5      1014             0                 0           3670        308         10.095654            1062              312               81.314742                642              590               92.000000              6654          110     478       134             0            0      6.607367               3072                                4132                              4116                     16224                  26                     98                       0                    534               138                   18                    222                      308                         284                          8                           2                       2                   192                 458                    492                      230                   0               4              502              224                       588                           194                        188                     74                       148
# 6       286             0                 0            578        938         65.773366            2262             2102               34.380874               1132               34                3.774356              6992           46     110        22             2            0     11.110138               1308                                4992                              2804                     25528                   8                      8                      54                    552                90                   82                    950                      834                         342                          6                          10                       2                     0                 512                   1400                      652                  14               0              166               54                       400                            44                        280                     16                        84
# 7       944             2                 0           5982       2534         84.550972            4206             1578               27.774398               1102             1008               80.622451              1022           94     484        64             2            6     11.540438               4128                                8158                              6048                      8176                   8                     68                      42                     14               254                  224                    258                      248                         450                         16                          10                       0                   130                  66                    326                     1070                  62               4               42               34                       198                            74                         32                     84                       152
# 8       966             2                 4           4992       1774         25.748068              58              362                8.653363               1876              638               78.902218              3742          142     666        16             0            2     11.451912               1228                                5796                              7200                     15530                 104                     36                      48                     54                60                   48                    252                      516                         178                          0                          12                      20                     0                 136                    122                     1100                 160               2              590               54                       434                            84                        204                    148                       134
# 9       532             0                 2           5778       1870          7.911898            3774             2400               11.990934                 70              442                3.009549              1744           86     184         4             0            0     11.195761               1894                                8698                              2762                     15754                  92                     40                      74                    788               164                  166                    110                      858                         348                          6                           8                       6                   146                  90                   1612                     1716                  96               2               20                6                        70                           224                         54                    186                        20
# 10      250             4                 0           1796       3006         99.092014            3064             1046               52.747074                246              798               47.376336              5094          172     664       156             2           12      7.205532               5562                                9674                              2194                     23644                  86                     54                      28                    762               148                   26                   1376                      902                         410                          2                           8                      14                   360                 446                    910                     3302                 122               0              640              186                       224                           112                        324                    316                       232
# 11      804             2                 0           6054       2774          9.927990            4770             1254               48.840399               1504              618                4.757059              8068            8     800        60             0            6     13.175137               4486                               12716                              3136                       146                  78                     64                      10                    582                40                   26                    686                       20                         368                          0                           4                      10                    14                 216                    816                      318                  54               8              672              142                       148                             4                        224                     70                        76
# 12     1060             4                 0           4744       2740         72.467159            3782             1734               44.569575               2312             1198               98.336069              7406          132     756       148             4            0      7.211979               5180                                 252                              9578                     20594                  64                     72                      42                   1008               214                  296                    298                      286                         320                          0                          12                       8                   488                 136                    944                     3020                  50               2              474               54                        78                            62                         44                    190                       162
# 13      192             8                 6            530       3430         85.420130            3918             2514               18.433867               1494              212                9.344993              5840           56     542        88             0            6      4.369360                116                               11866                              6824                      9392                 194                    114                      90                    754               322                   54                    634                      116                         206                          2                           2                      10                   342                 244                   1632                      402                 118               4              298              202                        36                           314                        234                    140                        62
# 14     1046             0                 2           1334       1692         76.911345            1826             1576               48.136959               1812              600               73.788845               704          118     658        16             0            8      3.821621               5282                                9456                              2712                     22500                 140                     18                      62                    998               288                  218                    780                      816                         452                          2                           8                       6                   100                 158                   1294                     3058                 156              10              146              136                       288                           240                        216                    248                       106
# 15     1138             4                 0           4518        158         24.372623            3490             2294               18.252331                690             1100                7.736889              7202           64     840       116             0            0      2.155553                660                                8692                              1034                      9256                  82                     42                      50                   1234               140                  220                    734                      974                         450                          0                           8                      14                   400                 320                    752                     1944                  52               0              826               50                       190                           280                        118                    266                       104
# 16      758             4                 4           6246       1204         73.525148            3266             1154                2.381301               1996              634               58.819693              7306           36     690        42             0            0      9.116960               5562                               14448                              3230                      3762                 158                     32                      26                    564                 0                   68                    146                      164                         522                          2                           6                       4                   156                  72                   1228                      614                  58               6              384              156                       552                           212                        298                    188                        30
# 17      174             0                 8           7330       1716         21.102572            4712               20               52.509719               1344              350               90.638620              9554           60     540       178             4            6      2.633884               1820                                1774                               682                     21326                  58                     72                       6                    200                12                   38                      4                       48                         424                          0                          16                      18                   188                 380                   1310                     2660                  22               6              504              176                       272                             2                        178                    162                       122
# 18      748             0                 6           5714       2588         34.456126            2300             2200               56.022591               2374              880               18.985876              7160           38     802        84             0            2     12.041541                470                                8408                              9590                      7866                  12                     62                      52                    656               126                   46                   1210                      948                         364                          0                           4                       8                    16                 356                   1004                     1784                  32               6              358              166                       528                           156                        290                    144                       102
# 19      850             0                 4            436       2382         13.503052            2068             1180               93.383784               1770              764               66.085187              5624           28     766       142             0            0     12.367804                546                                4718                              8438                     18528                  72                     86                      44                    370               226                  358                    910                      644                         366                          4                           4                       0                   364                 530                   1474                     2016                   0               6              220              148                       694                             6                        220                    220                        72
#
#     tacklesAgainst  totalFinalThirdPassesAgainst  oppositionHalfPassesTotalAgainst  ownHalfPassesTotalAgainst  totalPassesAgainst  yellowCardsAgainst  throwIns  goalKicks  ballRecovery  freeKicks   id    matches  awardedMatches
# 0         488                   3100                             9300                          2990                   12578                 56           1254       430         1630         438     11350    40            0
# 1         582                    780                            10906                         11310                    9674                 56           1004       520         2300         202     11234    40            0
# 2         530                   5780                            11516                          5322                   24328                118           1038       334         3824         606     11391    52            0
# 3         746                   7254                             3070                          1510                   16300                 24           1256       242          816         880     11207    28            0
# 4         338                   5896                             5896                          5592                   13490                100            214       520         3696         834     11416    50            0
# 5         262                   1346                            15300                          3958                   12744                 42            162       564         3358          92     11178    12            0
# 6         282                   6992                             1438                         10186                       2                 42            130       530         1678         668     11415    18            0
# 7         416                   5940                             6292                         17108                   27046                 84            894       398         1870         584     11233    50            0
# 8        1010                   4106                            12018                         11496                   11652                 22           1266       114         2618         606     11177    38            0
# 9         854                   3854                            15944                         14362                   29584                 48            972       240         3520         602     11326    38            0
# 10        948                   8016                             4696                            68                   29254                 18             28       514         1578         240     11325    48            0
# 11        644                   6076                             9868                         12410                   18008                162            878       168         3930         852     11136    18            0
# 12         96                   2716                             1822                          5578                   16608                 34            588       418         2052         360     11349    60            0
# 13        270                   3864                             1014                          5334                    3932                 58           1172       470         2300         514     11135     8            0
# 14        944                   2220                             6536                         12144                   17344                 96            870       430         2384         250     11300    64            0
# 15        164                   8196                            20094                           538                    9612                 28            274       538          638         138     11208    44            0
# 16        794                   1930                            14820                         16308                   34082                 38            996       102         2150         538     11299    18            0
# 17         52                    828                             5306                          9222                   13290                132           1174       438         1682         640     11097    44            0
# 18       1076                   2516                            13878                         10480                   20198                 46            566       188         3856         836     11390    56            0
# 19        880                   4694                            13002                         11370                   26478                114            252       518         2116         406     11096     6            0

# %%
teams = [
    ("http://www.sofascore.com/es/equipo/futbol/barcelona/2817#tab:squad", "Barcelona"),
    ("http://www.sofascore.com/es/equipo/futbol/real-madrid/2829#tab:squad", "Real Madrid"),
    ("http://www.sofascore.com/es/equipo/futbol/atletico-madrid/2836#tab:squad", "Atlético Madrid"),
    ("http://www.sofascore.com/es/equipo/futbol/sevilla/2833#tab:squad", "Sevilla FC"),
    ("http://www.sofascore.com/es/equipo/futbol/real-betis/2816#tab:squad", "Real Betis"),
    ("http://www.sofascore.com/es/equipo/futbol/villarreal/2819#tab:squad", "Villarreal CF"),
    ("http://www.sofascore.com/es/equipo/futbol/real-sociedad/2824#tab:squad", "Real Sociedad"),
    ("http://www.sofascore.com/es/equipo/futbol/athletic-club/2825#tab:squad", "Athletic Club"),
    ("http://www.sofascore.com/es/equipo/futbol/valencia/2828#tab:squad", "Valencia CF"),
    ("http://www.sofascore.com/es/equipo/futbol/celta-vigo/2821#tab:squad", "Celta de Vigo"),
    ("http://www.sofascore.com/es/equipo/futbol/getafe/2859#tab:squad", "Getafe CF"),
    ("http://www.sofascore.com/es/equipo/futbol/girona/24264#tab:squad", "Girona"),
    ("http://www.sofascore.com/es/equipo/futbol/osasuna/2820#tab:squad", "CA Osasuna"),
    ("http://www.sofascore.com/es/equipo/futbol/alaves/2885#tab:squad", "Deportivo Alavés"),
    ("http://www.sofascore.com/es/equipo/futbol/granada/33779#tab:squad", "Granada CF"),
    ("http://www.sofascore.com/es/equipo/futbol/las-palmas/6577#tab:squad", "Las Palmas"),
    ("http://www.sofascore.com/es/equipo/futbol/cadiz/4488#tab:squad", "Cádiz CF"),
    ("http://www.sofascore.com/es/equipo/futbol/mallorca/2826#tab:squad", "RCD Mallorca"),
    ("http://www.sofascore.com/es/equipo/futbol/rayo-vallecano/2818#tab:squad", "Rayo Vallecano"),
    ("http://www.sofascore.com/es/equipo/futbol/almeria/2858#tab:squad", "Almería")
]


import requests
from bs4 import BeautifulSoup
import pandas as pd

def fetch_players(url, team_name):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    players = []
    for link in soup.find_all('a', href=True):
        href = link['href']
        if '/es/jugador/' in href:
            parts = href.split('/')
            player_name = parts[-2]
            player_id = parts[-1]
            players.append({'Team': team_name, 'Name': player_name, 'ID': player_id})
    
    return pd.DataFrame(players)


results_df = pd.DataFrame()  # DataFrame vacío para almacenar todos los resultados

for url, team_name in teams:
    team_df = fetch_players(url, team_name)
    results_df = pd.concat([results_df, team_df], ignore_index=True)

# Guardar los resultados en un archivo CSV
results_df.to_csv('players_info.csv', index=False)
print("Datos guardados en 'players_info.csv'.")
# Out:
# Datos guardados en 'players_info.csv'.

# %% [markdown]
# #### Estadísticas de la liga de todos los jugadores

# %%
import requests
import pandas as pd

def fetch_player_statistics(player_id, player_name, team_name):
    url = f"http://www.sofascore.com/api/v1/player/{player_id}/unique-tournament/8/season/52376/statistics/overall"
    response = requests.get(url)
    data = response.json()

    if 'statistics' in data:
        stats = data['statistics']
        player_stats = {
            'Player Name': player_name,
            'Team': team_name,
            'Rating': stats.get('rating', None),
            'Total Rating': stats.get('totalRating', None),
            'Goals': stats.get('goals', None),
            'Assists': stats.get('assists', None),
            'Expected Goals': stats.get('expectedGoals', None),
            'Expected Assists': stats.get('expectedAssists', None),
            'Accurate Passes': stats.get('accuratePasses', None),
            'Inaccurate Passes': stats.get('inaccuratePasses', None),
            'Total Passes': stats.get('totalPasses', None),
            'Successful Dribbles': stats.get('successfulDribbles', None),
            'Yellow Cards': stats.get('yellowCards', None),
            'Red Cards': stats.get('redCards', None),
            'Shots On Target': stats.get('shotsOnTarget', None),
            'Total Shots': stats.get('totalShots', None),
            'Minutes Played': stats.get('minutesPlayed', None),
            'Appearances': stats.get('appearances', None)
        }
        return pd.DataFrame([player_stats])
    else:
        return pd.DataFrame()

# Leer CSV de jugadores
players_df = pd.read_csv('players_info.csv')

# DataFrame para almacenar todos los resultados
all_players_stats = pd.DataFrame()

# Iterar sobre cada jugador y obtener sus estadísticas
for index, row in players_df.iterrows():
    df = fetch_player_statistics(row['ID'], row['Name'], row['Team'])
    all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)

# Guardar el DataFrame final como CSV
all_players_stats.to_csv('all_players_statistics.csv', index=False)
print("Datos guardados en 'all_players_statistics.csv'.")
# Out:
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# C:\Users\mario\AppData\Local\Temp\ipykernel_19232\1967414008.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat([all_players_stats, df], ignore_index=True)
# Datos guardados en 'all_players_statistics.csv'.

# %%
import pandas as pd
file_path = 'all_players_statistics.csv'

# Cargar el DataFrame desde el CSV
df = pd.read_csv(file_path)

# Mostrar las primeras 10 filas del DataFrame
print(df.head(10))
# Out:
#       Player Name        Team      Rating   Total Rating  Goals  Assists  Expected Goals  Expected Assists  Accurate Passes  Inaccurate Passes  Total Passes  Successful Dribbles  Yellow Cards  Red Cards  Shots On Target  Total Shots  Minutes Played  Appearances
# 0  robert-lewandowski  Barcelona  7.232258      224.2      17      8.0        17.2691         3.037365            354               142              496              17                 5           0            39             87            2472           31
# 1        lamine-yamal  Barcelona  7.293939      240.7       4      4.0         4.6777         5.780314            721               137              858              54                 2           0            19             50            1865           33
# 2          joao-felix  Barcelona  7.085185      191.3       7      3.0         7.9856         2.558773            493                96              589              25                 3           0            23             56            1471           27
# 3            raphinha  Barcelona  7.265385      188.9       5      9.0         6.3745         4.923113            433               105              538              22                 2           1            19             51            1227           26
# 4         vitor-roque  Barcelona  6.509091       71.6       2      NaN         2.4657         0.031078             38                14               52               4                 1           1             5             11             276           11
# 5       ferran-torres  Barcelona  6.936000      173.4       7      2.0         5.3525         1.681804            308                79              387              10                 2           0            14             36            1098           26
# 6           guiu-marc  Barcelona  6.766667       20.3       1      NaN         0.7554         0.061575              8                 0                8               0                 1           0             1              4              82            3
# 7               pedri  Barcelona  7.155000      143.1       2      2.0         2.1414         3.624772            774               118              892              14                 3           0             4             11            1216           20
# 8     frenkie-de-jong  Barcelona  7.445000      148.9       2      NaN         0.6997         4.879607           1526               113             1639              13                 7           0             4              7            1637           20
# 9                gavi  Barcelona  7.133333       85.6       1      1.0         0.9486         1.372645            481                45              526              12                 5           0             4              9             943           12

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar el DataFrame desde un CSV
df = pd.read_csv('all_players_statistics.csv')


# Asegurarse de que las columnas 'Goals' y 'Assists' son numéricas
df['Goals'] = pd.to_numeric(df['Goals'], errors='coerce')
df['Expected Goals'] = pd.to_numeric(df['Expected Goals'], errors='coerce')

# Ordenar por goles y tomar los primeros 20 jugadores
top_scorers = df.sort_values(by='Goals', ascending=False).head(500)

plt.figure(figsize=(10, 8))
scatter = plt.scatter(top_scorers['Goals'], top_scorers['Expected Goals'], alpha=0.6, color='blue')

# Añadir títulos y etiquetas
plt.title('Scatter Plot de Goles vs Expected Goals')
plt.xlabel('Goles')
plt.ylabel('Expected Goals')

# Añadir etiquetas de nombres de jugadores
for i, point in top_scorers.iterrows():
    plt.text(point['Goals'], point['Expected Goals'], point['Player Name'])

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 10))  # Ajustar tamaño de figura para acomodar ambos plots

# Primer subplot para Goles vs Expected Goals
plt.subplot(1, 2, 1)  # 1 fila, 2 columnas, primer subplot
plt.scatter(top_scorers['Goals'], top_scorers['Expected Goals'], alpha=0.6, color='blue')
plt.title('Goles vs Expected Goals')
plt.xlabel('Goles')
plt.ylabel('Expected Goals')
plt.grid(True)

# Añadir etiquetas de nombres de jugadores para el primer gráfico
for i, point in top_scorers.iterrows():
    plt.text(point['Goals'], point['Expected Goals'], point['Player Name'])

# Segundo subplot para Expected Goals vs Expected Assists
plt.subplot(1, 2, 2)  # 1 fila, 2 columnas, segundo subplot
plt.scatter(top_scorers['Expected Goals'], top_scorers['Expected Assists'], alpha=0.6, color='green')
plt.title('Expected Goals vs Expected Assists')
plt.xlabel('Expected Goals')
plt.ylabel('Expected Assists')
plt.grid(True)

# Añadir etiquetas de nombres de jugadores para el segundo gráfico
for i, point in top_scorers.iterrows():
    plt.text(point['Expected Goals'], point['Expected Assists'], point['Player Name'])

plt.tight_layout()  # Ajusta automáticamente los parámetros del subplot para dar espacio entre ellos
plt.show()
